# %%
# !pip install requests beautifulsoup4
# !pip install selenium
# !pip install webdriver_manager
# !pip install selenium webdriver_manager
# !pip install webdriver_manager==3.4.2
# !pip install webdriver_manager
# !pip install --upgrade selenium
# Out:
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests) (2023.7.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4) (2.4)
# Requirement already satisfied: selenium in c:\users\user\anaconda3\lib\site-packages (4.14.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\user\anaconda3\lib\site-packages (from selenium) (1.26.16)
# Requirement already satisfied: trio~=0.17 in c:\users\user\anaconda3\lib\site-packages (from selenium) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\user\anaconda3\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\user\anaconda3\lib\site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\user\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\user\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\user\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: webdriver_manager in c:\users\user\anaconda3\lib\site-packages (4.0.1)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from webdriver_manager) (2.31.0)
# Requirement already satisfied: python-dotenv in c:\users\user\anaconda3\lib\site-packages (from webdriver_manager) (1.0.0)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\lib\site-packages (from webdriver_manager) (23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests->webdriver_manager) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->webdriver_manager) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->webdriver_manager) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->webdriver_manager) (2023.7.22)

# %%
import os
import time
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
import pandas as pd

# 設定你的YouTube API金鑰
api_key = 'AIzaSyCBwTej4XDj2HSD-5uCGbh74kxjK9rw_F4'

# 創建YouTube API客戶端
youtube = build('youtube', 'v3', developerKey=api_key)

# 定義搜索關鍵字
search_keyword = 'shorts'

# 初始化變數，用於儲存所有搜索結果
all_results = []

# 設定要取得的總數
total_results = 8000

# 在每次 API 請求後增加等待時間
wait_time = 5

# 創建一個 Counter 物件，用於統計 hashtag 字數
hashtag_counter = Counter()

# 每次請求的結果數量
results_per_request = 50

# 計數器，用於計算已獲得的結果數量
total_results_count = 0

# 每次請求的頁數
page_count = total_results // results_per_request

# 初始搜索請求
request = youtube.search().list(
    part='id,snippet',
    q=search_keyword,
    type='video',
    order='viewCount',
    maxResults=results_per_request
)

while len(all_results) < total_results:
    try:
        response = request.execute()
    except HttpError as e:
        if "timeout" in str(e):
            print(f"TimeoutError: Waiting {wait_time} seconds before retrying")
            time.sleep(wait_time)
            continue
        else:
            raise e

    # 處理搜索結果
    for item in response['items']:
        video_id = item['id']['videoId']
        video_title = item['snippet']['title']
        video_url = f'https://www.youtube.com/shorts/{video_id}'

        # 單獨請求影片的詳細資訊，包括hashtag
        video_request = youtube.videos().list(
            part='snippet',
            id=video_id
        )
        video_response = video_request.execute()

        # 檢查是否有hashtag
        if 'tags' in video_response['items'][0]['snippet']:
            video_hashtags = video_response['items'][0]['snippet']['tags']
        else:
            video_hashtags = []

        # 過濾掉指定的字詞
        words_to_remove = ['#kl bro biju rithvik', 'shorts', 'short', 'youtube shorts', 'shorts break', 'short break',
                           'shortsbreak', 'shorts break channel', '#shorts', 'Shorts']
        words_to_replace = {'kaamwali bai': 'Maid servant', 'bhai': 'brother', 'behan': 'sister', 'mukbang': 'hot pot',
                            'behen': 'sister', 'chotti': 'younger', 'badi': 'elder', 'choti': 'younger'}
        filtered_hashtags = filter_hashtags(video_hashtags, words_to_remove, words_to_replace)

        # 將過濾後的 hashtag 加入字數統計
        hashtag_counter.update(filtered_hashtags)

        # 將資料添加到結果列表
        all_results.append({'Title': video_title, 'URL': video_url, 'Filtered Hashtags': filtered_hashtags})

    # 更新計數器
    total_results_count += len(response['items'])

    # 检查是否已经达到目标数量
    if total_results_count >= total_results:
        break

    # 檢查是否有下一頁的結果
    if 'nextPageToken' in response:
        next_page_token = response['nextPageToken']
        # 更新請求以獲取下一頁的結果
        request = youtube.search().list(
            part='id,snippet',
            q=search_keyword,
            type='video',
            order='viewCount',
            maxResults=results_per_request,
            pageToken=next_page_token
        )
    else:
        # 若無下一頁結果，跳出迴圈
        break

# 列印所有搜索結果及其hashtag，同時進行字數統計
for result in all_results:
    print(f"{result['Title']}: {result['URL']}")
    print(f"Filtered Hashtags: {result['Filtered Hashtags']}")
    print()

# 生成文字雲
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(hashtag_counter)

# 顯示文字雲
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# 將結果列表轉換為 DataFrame
df = pd.DataFrame(all_results)

# 將 DataFrame 儲存到 Excel 檔案
excel_filename = 'youtube_shorts_data.xlsx'
df.to_excel(excel_filename, index=False)
print(f"Data saved to {excel_filename}")
# Out:
# Using CHOPSTICKS Be Like... #shorts: https://www.youtube.com/shorts/pFtsvQuefXQ
# Filtered Hashtags: ['funny', 'comedy']
#
# She Was &quot;One Minute&quot; Away From Disaster! #shorts: https://www.youtube.com/shorts/ACOV0xtRUQ8
# Filtered Hashtags: ['dress', 'diy', 'diy projects', 'diy activities', 'diy decor', 'do it yourself', 'diy home decor', 'diy room decor', 'crafts', 'diy ideas', 'diy hacks', 'how to make', 'diy project', 'dresses', 'dress disco polo', 'diy thrift flip', 'diy ikea hacks', 'diy on a budget', 'liz fenwick diy', 'only dresses', 'tiktok diy', 'dress dance', 'dress 2020', 'easy diy', 'diy crafts', 'life hacks', 'how to', 'tips', 'ideas', 'how to make everything', 'howto', 'met gala', 'red carpet']
#
# Adhemz VS Self Defence kid training: https://www.youtube.com/shorts/D6HFAFiHD1w
# Filtered Hashtags: []
#
# Tom 🍓 Jerry (Rithvi&amp;Kavi)Real End Twist 😂🎈 #shorts: https://www.youtube.com/shorts/K6Oi9_4tm6w
# Filtered Hashtags: []
#
# Spider-Man Vs Rhino || Spider Man Attitude Status Andrew || Edited By Raihan Nion #shorts #spiderman: https://www.youtube.com/shorts/Ul1pb7Nf-zA
# Filtered Hashtags: []
#
# funny vadieo subscribe for more vadieos #shorts: https://www.youtube.com/shorts/aEBxl6x5Ym8
# Filtered Hashtags: []
#
# Monke splat: https://www.youtube.com/shorts/VEWZvWPC490
# Filtered Hashtags: ['Vector', 'Vector TikTok', 'Despicable me TikTok', '@vector', '@_vector_', '_vector_ tiktok', 'Vector nerf tiktok', 'Vector nerf war', 'Vector nerf gun war', 'vector nerf gun', 'vector nerf guns', 'Despicable me tiktok', 'Vector nerf', 'Nerf vector', 'Vector hahaha', 'Vector from tiktok', '_vector_', 'vector despicable me', 'despicable me vector', 'despicable me', 'minions', 'tiktok', 'tiktok trend', 'tiktok newest', 'tiktok compilation', 'best compilation', 'new compilation', 'compilation', 'viral trend', 'nerf', 'funny', 'funny compilation']
#
# respect 💀🥵 #shorts: https://www.youtube.com/shorts/5V230M8hJE0
# Filtered Hashtags: []
#
# Jelly soda: https://www.youtube.com/shorts/0VuC1DHZhHw
# Filtered Hashtags: ['Vector', '_vector_', 'vectorr', 'vvector', '_vector', 'vector_', '__vectorr', '@vector', '@_vector_', 'vector tiktok', 'vector nerf', 'youtube vector', 'vector youtuber', 'vector youtube', 'vector reacts', 'vector video', 'vector reaction', 'vector react', 'vector react video', 'vector compilation', 'nerf vector', 'vector despicable me', 'vector funny', 'despicable me vector', 'vector oh yeah', 'vector shorts', 'vector youtube shorts', 'shorts vector', 'youtube shorts vector', 'vector yt', 'vectir', 'vektor', 'vectoor', 'victor', '_victor_', 'victor react']
#
# &quot;Together&quot; Short | TROLLS: https://www.youtube.com/shorts/y47zSNXkkDg
# Filtered Hashtags: ['DreamWorksTV', 'DreamWorks Animation', 'DreamWorks', '夢工場動畫', 'Something New', 'Family Entertainment', 'YouTube Kids', 'TROLLS', 'trolls', 'new trolls', 'trolls short', 'trolls 2', 'trolls series', 'trolls characters', 'satin and chenille']
#
# Gadgets, Smart Appliances, Kitchen Utensils/Home Cleaning/Inventions P200  #shorts: https://www.youtube.com/shorts/o4CZDdjDFzg
# Filtered Hashtags: []
#
# 0 đồng ăn gì? p61 #shorts #tiktok #foryou #xuhuong #fyp #langlieu: https://www.youtube.com/shorts/2_pMBCeNV6g
# Filtered Hashtags: ['tiktok', 'tik tok ẩm thực', 'ẩm thực', '1 đồng mua được gì', 'một đồng mua được gì', 'ẩm thực trung quốc', 'spicy food', '1 dong mua duoc gi', 'am thuc trung quoc', 'tik tok 1 dong', 'tik tok china', 'tik tok', 'lang lieu tiktok', '1 đồng', '1 tệ', 'mot dong mua duoc gi', 'lang lieu', 'chinese food', 'ẩm thực 1 đồng', '1 dong', '1 xu', 'cuisine', '1 đồng ăn gì', 'what can $1 buy', 'spicy food challenge', 'khana', 'hot pot', '1 dong an gi', '$1 can buy anything', 'extreme spicy food', 'tiktok triệu view', 'tiktok 2023']
#
# कामवाली बाई और विराट कोहली 🏏😂 IPL | Kaamwali Bai Part 16 #Shorts #Shortsbreak: https://www.youtube.com/shorts/R7rWBW9pNG8
# Filtered Hashtags: ['Maid servant', 'Maid servant comedy', 'kaamvali bai', 'maid', 'types of maid', 'desi maid', 'comedy shorts', 'shila ki comedy', 'types of Maid servant', 'kaam wali bai', 'kaamwali', 'funny Maid servant', 'kamwali bai', 'kaam wali bai series', 'kamwali bai comedy video', 'kamwali bai shila', 'kamwali bai short', 'Maid servant new video', 'कामवाली बाई', 'didi', 'Maid servant shila comedy', 'ipl', 'ipl 2022', 'kamwali bai in ipl', 'stadium', 'shila', 'kamwali sheela', 'kamwali bai ipl']
#
# @ponycycle The best gift for kids ❤️ #filaretiki #shorts: https://www.youtube.com/shorts/6WMn75br2kU
# Filtered Hashtags: []
#
# Random Mint food MUKBANG🤢 #shorts: https://www.youtube.com/shorts/JWKTXXRMyEU
# Filtered Hashtags: []
#
# #shortsvideo #shorts: https://www.youtube.com/shorts/kjPfsJaO-k8
# Filtered Hashtags: []
#
# Chili Crab Pizza @ChefRush: https://www.youtube.com/shorts/4MIJpa3d9r4
# Filtered Hashtags: ['food', 'recipe', 'tasty', 'dinner', 'snack', 'lunch']
#
# Barbie Makeup Transformation | Makeup By 6 Year Old Kassie: https://www.youtube.com/shorts/fH3tez7eyIU
# Filtered Hashtags: ['barbie', 'barbie makeup', 'makeup', 'barbie makeover', 'barbie makeup tutorial', 'tiktok viral', 'barbie movies', 'shab and kassie']
#
# respect 😱🤯🔥: https://www.youtube.com/shorts/g_G5r8OtPa0
# Filtered Hashtags: ['respect', 'respect video', 'respect shorts', 'viral', 'yyoutubeshort', 'respect earth 999+']
#
# Kunjuttan Rocks Epi : 9 | Ball Ferry | M4 Tech | #shorts: https://www.youtube.com/shorts/QacjCYPRSuM
# Filtered Hashtags: []
#
# शीला दीदी aur Rickshaw 🤣 | Kaamwali Bai - Part 44 | #shorts | Shorts Break: https://www.youtube.com/shorts/AbLt2rjjqm4
# Filtered Hashtags: ['Maid servant', 'Maid servant comedy', 'shila ki comedy', 'types of Maid servant', 'kaam wali bai', 'kaamwali', 'funny Maid servant', 'kamwali bai', 'kaam wali bai series', 'kamwali bai shila', 'kamwali bai short', 'Maid servant new video', 'कामवाली बाई', 'Maid servant shila comedy', '#कामवाली बाई शॉर्टस', 'कामवाली बाई गंगुबाई काठीवाडी', 'शीला बाई कॉमेडी', 'Maid servant sheela comedy', 'prashant and sheela', 'prashant and shila video', 'sheela didi aur rickshaw wala']
#
# छोटी बेहेन और Model Life 😆 | Badi Behen Vs Choti Behen - Part 6 #Shorts #Shortsbreak: https://www.youtube.com/shorts/3TRo7BcnbaI
# Filtered Hashtags: ['elder sister', 'younger sister', 'elder sister', 'sister hogi teri', 'brother sister', 'best friends', 'elder sister vs younger sister aditi sharma', 'family', 'sister vs sister', 'sister brother', 'sister vs sister', 'younger sister vs elder sister', 'sister sister ka pyaar', 'chhoti sister', 'elder sister vs chhoti sister', 'fight', 'the payal jain new video', 'siblings', 'Maid servant', 'sisters', 'sister vs sister video', 'sisters fight', 'siblings squad', 'siblings fight', 'problems with heels']
#
# honey bee 🐝 #instagram #reels #tamil #trending #troll #kesavkutty #shorts #songs #honey: https://www.youtube.com/shorts/6QwuHf3FZZk
# Filtered Hashtags: []
#
# Funny baby reaction on the beach || #shorts: https://www.youtube.com/shorts/n_6YPvWcFLA
# Filtered Hashtags: ['Funny baby reaction on the beach ||', 'Funny baby playing on the beach', 'Baby on beach', 'Baby go beach', 'Baby swimming', 'Baby bathing', 'Baby laughing video', 'Baby video compilation', 'Baby video 2023', 'Baby reaction video', 'Baby', 'Baby eating', 'Baby first time', 'Baby name']
#
# Spider-Man funny video 😂😂😂 | SPIDER-MAN Best TikTok May 2023 Part35 #shorts #sigma: https://www.youtube.com/shorts/7dUY12c4Xwo
# Filtered Hashtags: ['TikTok', 'spiderman', 'meme', 'memes', 'TikTokChallenge', 'funnyvideo', 'funnytiktok', 'mostfunny', 'tiktokcompilation\u200b', 'funny', 'fyp', 'foryoupage', 'funnyshorts', 'shortsfunny', 'viral']
#
# इतना सारा काम! 😂🥵 | Kaamwali Bai - Part 36 #Shorts #Shortsbreak #takeabreak: https://www.youtube.com/shorts/59xxdLvCAEs
# Filtered Hashtags: ['Maid servant', 'Maid servant comedy', 'kaamvali bai', 'shila ki comedy', 'types of Maid servant', 'kaam wali bai', 'kaamwali', 'funny Maid servant', 'kamwali bai', 'kaam wali bai series', 'kamwali bai comedy video', 'kamwali bai shila', 'kamwali bai short', 'Maid servant new video', 'कामवाली बाई', 'Maid servant shila comedy', '#कामवाली बाई शॉर्टस', 'कामवाली बाई गंगुबाई काठीवाडी', 'शीला बाई कॉमेडी', 'Maid servant sheela comedy', 'Maid servant series', 'cupboard ki safai']
#
# Salute to Indian army 🇮🇳❤️ #shorts: https://www.youtube.com/shorts/e-jGiRwiBq8
# Filtered Hashtags: []
#
# printer😍New Gadgets, Smart Appliances tech266 Inventions #shorts #gadgets: https://www.youtube.com/shorts/V377Nw3IY9k
# Filtered Hashtags: []
#
# Clip thú vị thỏa mãn người xem (p4039) #shorts: https://www.youtube.com/shorts/Dg8x2P99nmM
# Filtered Hashtags: []
#
# Tutorial mit meine Zwillingsschwester! #shorts: https://www.youtube.com/shorts/zShlRy6zDmc
# Filtered Hashtags: ['#alessandraperticone', '#switzerland', '#swiss', '#italiana', '#tutorial', '#transition', 'youtubeshorts']
#
# Anaconda Snake Chasing Boy video 🐍 #Shorts: https://www.youtube.com/shorts/ZjXM5WgPyBk
# Filtered Hashtags: ['Snake', 'Anaconda', 'Big snake', 'Short', 'saamp', 'nagin', 'naagin', 'snake video', 'saamp video']
#
# Bring it On #shorts: https://www.youtube.com/shorts/zsIwarFkDVk
# Filtered Hashtags: ['dans', 'dansam', 'dance', 'sergiu', 'portnoi', 'cristina', 'pamflet', 'comic', 'amuzant']
#
# wait for it… 😱 #shorts: https://www.youtube.com/shorts/-q_iWzlHjqU
# Filtered Hashtags: []
#
# respect 😱🤯🔥#shorts: https://www.youtube.com/shorts/J3l2hPVe0BU
# Filtered Hashtags: ['respect', 'respect video', 'respect shorts', 'viral', 'yyoutubeshort', 'respect earth 999+']
#
# trying to recreate couples poses #shorts: https://www.youtube.com/shorts/uZFbRMRtJj0
# Filtered Hashtags: ['matt and abby', 'abby and matt', 'matt and abby titkok']
#
# Tom 🍓 Jerry (Rithvi&amp;Kavi)Real End Twist 😂🎈 #shorts: https://www.youtube.com/shorts/1EXXMBA0Pn8
# Filtered Hashtags: []
#
# The best kids 🔥🔥🔥 #filaretiki #social #shorts: https://www.youtube.com/shorts/edyh71THv_8
# Filtered Hashtags: []
#
# When he see’s the photo!😮😱 #Shorts: https://www.youtube.com/shorts/5GWYHYrwVCQ
# Filtered Hashtags: []
#
# Tom 🍓 Jerry (Rithvi&amp;Kavi) Real End Twist 😂🎈 #shorts: https://www.youtube.com/shorts/8dr1CzYLnyA
# Filtered Hashtags: []
#
# छुट्टी मिल गयी 😁😂 | Kaamwali Bai - Part 61 | #shorts | Shorts Break: https://www.youtube.com/shorts/HElP_uw4P80
# Filtered Hashtags: ['Kaamwali bai', 'Maid servant sheela', 'sheela didi', 'prashant brotherya', 'sayali sonule', 'sayali prashant', 'prashant kulkarni', 'aparna tandale', 'kamwali bai', 'Maid servant comedy', 'Relatable comedy', 'lottery comedy', 'Maid servant', 'shila ki comedy', 'types of Maid servant', 'funny Maid servant', 'kaam wali bai series', 'kamwali bai shila', 'kamwali bai short', 'कामवाली बाई', '#कामवाली बाई शॉर्टस', 'sheela didi comedy', 'कामवाली बाई और छुट्टी']
#
# New Gadgets, Smart Appliances, Kitchen Tools, Utensils, Home Cleaning/Beauty, Accessories 😍 #shorts: https://www.youtube.com/shorts/vpJmgkZW9bI
# Filtered Hashtags: []
#
# Ab to me top karunga😂 #shorts #funny #comedy: https://www.youtube.com/shorts/jrSfobS0698
# Filtered Hashtags: []
#
# Ek Harami Bacha 😂 || Top Lockdown Viral Videos || Priyal Kukreja #shorts #ytshorts: https://www.youtube.com/shorts/j7sb6GUJwic
# Filtered Hashtags: []
#
# Ye Race Toh Mein hi Jitugi  🏆 | Mk Studio Yt Shorts: https://www.youtube.com/shorts/HVuW1v2nu1E
# Filtered Hashtags: ['mk studio', 'mk studio shorts', 'shorts story', 'story', 'new story', 'garib ki story', 'garib', 'garib ka majak', 'ishu', 'payal', 'kunal', 'shorts video', 'youtube shorts video', 'funny shorts', 'hindi story video', 'viral shorts', 'viral shorts video', 'story video', 'heart touching story video', 'very sad story', 'Motivation story shorts video', 'shorts story videos', 'viral story video', 'sad video', 'moral story shorts', 'meri ma', 'bandeya song', 'race', 'jesa ka tesa', 'race video', 'racing video', 'shorts story video']
#
# Wada pura kiya 🤣 #shorts #funny: https://www.youtube.com/shorts/i2oNOdUdGjw
# Filtered Hashtags: []
#
# Good dad 😊 Sonsi family #shorts TikTok: https://www.youtube.com/shorts/8qczqGUAAh4
# Filtered Hashtags: []
#
# Utah Moms on Nov 1st: https://www.youtube.com/shorts/LlsHmTt1WUU
# Filtered Hashtags: ['Utah moms', 'Utah mom', 'Utah', 'Draper moms', 'Jane', '@jane', 'Jane insane', 'Salt Lake City', 'Influencer moms', 'Mom bloggers', 'Christmas decor', 'Christmas time is here', 'November 1', 'Halloween is over', 'Christmas decorating', 'Moms be like', 'Mom humor', 'Sahm']
#
# आजसे No Indian चीज़े 😁 | #shorts | Shorts Break: https://www.youtube.com/shorts/xIRGhLthksA
# Filtered Hashtags: ['Maid servant', 'Maid servant comedy', 'shila ki comedy', 'types of Maid servant', 'kaam wali bai', 'kaamwali', 'funny Maid servant', 'kamwali bai', 'kaam wali bai series', 'kamwali bai shila', 'kamwali bai short', 'prashant and shila video', 'singapore', 'sayali in singapore', 'aajse no indian', 'indians in singapore', 'types of indians', 'types of people']
#
# ultimate cheetos grilled cheese #shorts: https://www.youtube.com/shorts/dOOOeyBAQxQ
# Filtered Hashtags: ['asmr', '\xa0zach choi', 'zachchoi', 'zach choi asmr', 'hot pot', '먹방', '\xa0쇼', '\xa0이팅', '\xa0사운드', '\xa0korean asmr', 'asmr eating', 'asmr eating no talking', 'asmr hot pot', 'asmr hot pot no talking', 'grilled cheese', 'cheese', 'fried cheese']
#
# Give Good🥹❤️👻 BOOMERANG #shorts: https://www.youtube.com/shorts/IGp5rkCH9bQ
# Filtered Hashtags: []
#
# खाना बना है? 😬😂 |  Kaamwali Bai - Part 51 | #shorts | Shorts Break: https://www.youtube.com/shorts/e5Ajc1liDdk
# Filtered Hashtags: ['Maid servant', 'Maid servant comedy', 'shila ki comedy', 'types of Maid servant', 'kaam wali bai', 'funny Maid servant', 'kaam wali bai series', 'kamwali bai shila', 'kamwali bai short', 'Maid servant new video', 'कामवाली बाई', '#कामवाली बाई शॉर्टस', 'कामवाली बाई गंगुबाई काठीवाडी', 'शीला बाई कॉमेडी', 'Maid servant sheela comedy', 'aparna tandale', 'khana bana hai?', 'sayali sonule', 'sheela didi', 'sheela didi comedy']
#
# Things every 10 year old does😂♥️ | Raj Grover | #shorts: https://www.youtube.com/shorts/GlPmKjoTFS8
# Filtered Hashtags: ['Things every 10 year old does', '10 year olds', '#minku', 'Minku raj grover', 'Raj grover', 'Raj grover childhood comedy', 'Comedy', 'Funny', 'Relatable', 'Raj grover minku', 'Minku shorts', 'Raj grover Shorts', 'Raj grover comedy', 'Raj grover funny videos', 'Raj grover relatable videos', 'Comedy shorts', 'Funny shorts', 'Relatable shorts']
#
# Tom 🍓 Jerry (Rithvi&amp;Kavi)Real End Twist 😂🎈 Mango 🍒#shorts: https://www.youtube.com/shorts/ScRlmf8LqZk
# Filtered Hashtags: []
#
# A Mickey Mouse Cartoon : Season 1 Episodes 1-10 | Disney Shorts: https://www.youtube.com/shorts/VBKgPmS5Fyw
# Filtered Hashtags: ['the walt disney company', 'Disney videos', 'Disney', 'Disney Youtube', 'Mickey Mouse', 'Mickey Cartoons', 'Mickey Shorts', 'New Mickey Mouse Cartoons', 'mickey mouse cartoons', 'classic mickey mouse', 'pluto', 'goofy', 'donald duck']
#
# माँ आ रही है 😆 | Husband Vs. Wife - Part 27 | #shorts | Shorts Break: https://www.youtube.com/shorts/jqNBW2paHyA
# Filtered Hashtags: ['husband vs wife', 'husband', 'wife', 'husband wife comedy', 'husband and wife comedy', 'husband vs wife fight', 'husband vs wife comedy', 'Maid servant', 'brotheryya', 'husband and wife', 'husband wife fight', 'husband wife jokes', 'husband and wife comedy shorts', 'husband wife relationship', 'husband wife jokes in hindi', 'Maid servant sheela comedy', 'hiding from wife', 'prashant', 'sayali', 'sayali sonule', 'prashant kulkarni', 'maa', 'maa aa rahi hai']
#
# BIP HOUSE / БИП ХАУС #SHORTS: https://www.youtube.com/shorts/hu65vgUZzEo
# Filtered Hashtags: ['бип хаус', 'бипхаус', 'бип', 'мона', 'луна', 'рахат', 'рэм', 'даулет', 'диас', 'сикстирич', 'даклет', 'моналеми', 'лунамккал', 'рахат масак', 'bip', 'bip house', 'monalemi', 'lunamccalll', 'rakhat masaq', 'thedaqlet', 'daqlet', 'sixtyrich', 'sixty rich', 'yolo house', 'йоло хаус', 'тикток хаус', 'тикток', 'tiktok house', 'сливки']
#
# कामवाली बाई और New Year | Part 6 #Shorts #TKFShorts #TKF: https://www.youtube.com/shorts/rZRZ0wjUwf4
# Filtered Hashtags: ['Entertainment', 'funny', 'tkf', 'bestreels', '2021', 'BYN', 'Best comedy shorts', 'reels', 'comedy reels', 'Trakin Ke Funde', 'Hindi Comedy', 'comedy videos', 'best comedy', 'types of people', 'tkf shorts', 'comedy shorts', 'trending shorts', 'trending comedy video', 'Maid servant', 'kaamvali bai', 'Maid servant comedy', 'every maid ever', 'maid', 'types of maids', 'indian maids', 'new year party', 'new year 2022', 'new year party 2022', 'best new year', 'house party']
#
# When it pops!: https://www.youtube.com/shorts/7pDym6u_uNQ
# Filtered Hashtags: ['justin flom', 'jflo', 'magic trick', 'magic', 'sleight of hand', 'tricks', 'card trick', 'magic block party', 'wizard wars', 'magic road trip']
#
# I Cured @MrBeast’s Fear Of Heights: https://www.youtube.com/shorts/0ENZe0ckmxA
# Filtered Hashtags: []
#
# Respect 😍😍💯🔥🔥#shorts: https://www.youtube.com/shorts/Nq_XxcT6R3I
# Filtered Hashtags: []
#
# Activating my THICK Pink Posca Mop’r Marker! #shorts: https://www.youtube.com/shorts/t2g6Fsibb4s
# Filtered Hashtags: ['posca markers', 'posca', 'kirby', 'activating', 'thick marker', 'activating my thick posca marker', 'shorts feed', 'viral', 'drawing kirby', 'how to draw kirby', 'paint marker', 'satisfying', 'art', 'tiktok', 'popular', 'explore', 'nashvibes', 'activate', 'marker', 'activating and drawing', "posca mop'r", "mop'r", 'graffiti', 'tagging', 'adri artsy', 'gawx', 'copic', 'ohuhu']
#
# मुझे भी आना है 🤣 | Badi Behen Vs. Choti Behen - Part 12 #Shorts #Shortsbreak #takeabreak: https://www.youtube.com/shorts/9ug8W0atSUg
# Filtered Hashtags: ['elder sister', 'younger sister', 'elder sister', 'sister hogi teri', 'brother sister', 'best friends', 'elder sister vs younger sister aditi sharma', 'family', 'sister vs sister', 'sister brother', 'sister vs sister', 'younger sister vs elder sister', 'sister sister ka pyaar', 'chhoti sister', 'elder sister vs chhoti sister', 'fight', 'the payal jain new video', 'siblings', 'Maid servant', 'sisters', 'sister vs sister video', 'sisters fight', 'siblings squad', 'siblings fight', 'Maid servant sheela comedy']
#
# 🤣🤪 Bad Day in Women&#39;s Sports #shorts: https://www.youtube.com/shorts/F4dIxethVAY
# Filtered Hashtags: []
#
# Sad story 🥺❤️ | jaanvi patel | #shorts #jaanvipatel: https://www.youtube.com/shorts/sZrfOAHq9u4
# Filtered Hashtags: []
#
# Lion Jump🦁: https://www.youtube.com/shorts/G8k-eD53vbI
# Filtered Hashtags: ['dean schneider', 'dean schneider youtube', 'youtube dean schneider', 'animals', 'nature', 'wildlife', 'vlog', 'compilation', 'Wildlife animals', 'wild animals', 'animal compilation', 'animal vlog', 'tiger', 'lion', 'lion pride', 'hakuna mipaka', 'african wildlife', 'african animals', 'rhino', 'northern white rhino', 'monkey', 'part\rof the lion pride', 'living with lions', 'hyena']
#
# BAILE PA TIK TOK💃🏻 #shorts #santioficial: https://www.youtube.com/shorts/SiCKtpQ-3Nk
# Filtered Hashtags: ['comedia', 'comedy', 'comedyhumor', 'comedia&humor', 'humormexicano', 'yolo aventuras', 'picus', 'daniel el travieso', 'cachetes', 'el chavo del 8', 'comedia colombiana', 'comedia latina', 'comedia mexicana', 'mikel tube', 'tendencia', 'TENDENCIA', 'DIVERSION', 'juego', 'reto', 'retos', 'retos divertidos', 'solo juego', 'jugando con agua', 'adivina', 'adivinando', 'jugando con el agua', 'reto entre amigos', 'yoloaventuras', 'alejo igoa', 'ALEJO IGOA', 'AMIGOS', 'DIVERSION ENTRE AMIGOS', 'PICUS', 'LAS RATONCITAS', 'MIKEL TUBE', 'SHORT', 'videos divertidos']
#
# bohot dhandhi hai 😂 #funny #comedy #realfoolsteam #shorts: https://www.youtube.com/shorts/mTKqSJrQxz8
# Filtered Hashtags: []
#
# Life Doodles | Chewing gum is crying 😢 #lifedoodles #doodle #shorts #bubblegum #gum #shortvideo: https://www.youtube.com/shorts/-1XReFlha3M
# Filtered Hashtags: []
#
# HE&#39;S WORKING LATE 🧐: https://www.youtube.com/shorts/QE3H-OvUFM0
# Filtered Hashtags: []
#
# AC में काम करूंगी 😆 | Kaamwali Bai - Part 66 | #shorts | Shorts Break: https://www.youtube.com/shorts/wjgLepRmGpA
# Filtered Hashtags: ['Kaamwali bai', 'Maid servant sheela', 'sheela didi', 'prashant brotherya', 'sayali sonule', 'sayali prashant', 'prashant kulkarni', 'aparna tandale', 'kamwali bai', 'Maid servant comedy', 'lottery comedy', 'Maid servant', 'shila ki comedy', 'types of Maid servant', 'funny Maid servant', 'kaam wali bai series', 'kamwali bai shila', 'kamwali bai short', 'कामवाली बाई', '#कामवाली बाई शॉर्टस', 'sheela didi comedy', 'ac mein kaam karungi']
#
# 🤩 Smart Appliances, Gadgets For Every Home/ Versatile Utensils (Inventions &amp; Ideas) #shorts: https://www.youtube.com/shorts/gOpCX6RjnQw
# Filtered Hashtags: []
#
# Salute to Indian Army❤️🇮🇳Is video ke liye ek like to banta he🙏🏻 #youtubeshorts #emotional #army￼: https://www.youtube.com/shorts/jIuMU7-0sUU
# Filtered Hashtags: []
#
# World&#39;s Smallest Pasta: https://www.youtube.com/shorts/eE5TJKZ0-jg
# Filtered Hashtags: ['pasta', 'mini-cooking', 'Nick DiGiovanni', 'Cooking', 'Food', 'Chef', 'Recipe', 'Gordon Ramsay', 'Kitchen', 'ASMR', 'MasterChef', 'Osmo Salt', 'TikTok', 'Salt Bae', 'Uncle Roger', 'Jamie Oliver', 'Knife Throw', 'Knife Drop']
#
# Activating my THICK GREEN Posca Marker and Drawing with it! #shorts: https://www.youtube.com/shorts/Pmn3QfE0_xg
# Filtered Hashtags: ['posca markers', 'posca', 'activating', 'green', 'thick', 'activating my thick posca marker', 'shrek', 'adri artsy', 'drawing', 'painting', 'activating marker', 'how to draw', 'satisfying']
#
# Lays Chicken #shorts: https://www.youtube.com/shorts/FWXrfLHg0oI
# Filtered Hashtags: []
#
# Ultimate chocolate moist cake #shorts #cooking #recipe: https://www.youtube.com/shorts/C-V_kSnBSwg
# Filtered Hashtags: ['チョコレート', 'Chocolate', '料理', 'お菓子作り', '手作り', 'レシピ', 'sweets', 'スイーツ', 'cooking', 'Recipe', 'cooking sounds', '作り方', '音フェチ', 'asmr', '作業音']
#
# Madam se Badla😈😂|| @bobbyprankster  Gulshan kalra #shorts: https://www.youtube.com/shorts/-0wNJw9yUHw
# Filtered Hashtags: []
#
# ASMR Dirt and stone removal in deep belly button| Remove Huge Navel Stone Animation: https://www.youtube.com/shorts/Ml9kRCMO6Ic
# Filtered Hashtags: []
#
# Lisa Noticed Me: https://www.youtube.com/shorts/fj1D3DMi1s8
# Filtered Hashtags: []
#
# जीना हराम करदिया | Le Gayi | new funny video | #shorts #funny #shortvideo #comedy: https://www.youtube.com/shorts/WjJcbHDY-bA
# Filtered Hashtags: []
#
# CGI Animated Short Film: &quot;Mind Games&quot; by Jiaqi Emily Yan | CGMeetup: https://www.youtube.com/shorts/TvRhfaouBHs
# Filtered Hashtags: ['animated short film', 'cgmeetup', 'cg meetup', 'cgi animated short film', 'short film animation', 'short animated films', 'cgi', '3d', 'animation short film', 'short film', 'cgi animation', 'animation', 'short animation', 'animated short films', 'animations short films', 'pixar short films', 'short films animation', 'short films', 'animated shorts', 'cgi short film', 'short film cartoon', 'mind games', 'mind games animated short film', 'mind games short film', 'animated', 'cgi movies', '3d animated short film', '3d animation', 'kids']
#
# Unboxing Cute Stationary Set // Unicorn Stationary Set #shorts #youtubeshorts: https://www.youtube.com/shorts/5Vw-fBcBXZo
# Filtered Hashtags: ['girl crafts', 'diy', 'DIY Ideas', 'crafts', 'do it yourself', 'how to', 'howto', 'girly crafts', 'how to make', 'tutorial', 'diy activities', 'diy projects', 'handcraft', 'life hacks', 'tips', 'tricks', 'trucos', 'Hacks', 'stationary', 'unboxing', 'asmr', 'stationary set', 'electric stationary set', 'unicorn stationary set', 'stationary kit', 'electric eraser', 'electric pencil sharpener']
#
# Sigma Pellam Episode -3 #shorts #telugu #funny #comedy #sigmagirl: https://www.youtube.com/shorts/EWFO6CXcNUM
# Filtered Hashtags: []
#
# pan flavour😂 apko kon sa flavour pasand he😜 #shorts #viral #emotional #youtubeshorts #short: https://www.youtube.com/shorts/dzIb15ZeOHw
# Filtered Hashtags: []
#
# Fake Eyeball Prank #shorts: https://www.youtube.com/shorts/tlDOiRufFak
# Filtered Hashtags: ['skits', 'skitsful', 'tik tok', 'tik tok prank', 'prank wars', 'Funny Pranks phone', 'American Pranks', 'American Prank', 'prank ideas', 'Top prank', 'SMOL', '123go', 'fun', 'funny', 'challenge', 'prank', 'play', 'pranks', 'hacks', 'comedy', '5 minute crafts', 'la la life', 'troom troom', 'crafty panda', 'youtubeshorts', 'tutorial', 'DIY Tricks', 'TikTok Pranks', 'Tutorial', 'How To', 'Life Hacks', 'Hacks\nTricks\nDIY', 'tricks', 'tiktok', 'tiktok compilation', 'family', 'DIY', 'how to', 'howto', 'xo tik tok', 'xo team tik tok']
#
# मुन्ना का दोस्त 🤣 | Maa Beta | #shorts | Shorts Break: https://www.youtube.com/shorts/G1Y-fDE4QUQ
# Filtered Hashtags: ['comedy shorts', 'shorts break comedy', 'short break channel', 'maa beta funny video', 'maa beta comedy', 'maa beta comedy video', 'maa aur beta comedy', 'maa aur nalayak beta comedy', 'maa bete ka comedy', 'maa beta', 'mom', 'mother', 'mom vs me', 'mami and mi', 'me vs mom', 'my mom', 'types of mom', 'family comedy', 'shashank swamod', 'sayali sonule', 'savage mom', 'relatable', 'relatable shorts', 'dhokebaaz dost', 'harami dost']
#
# Boys life 😢 #shorts #funny: https://www.youtube.com/shorts/RvOzuxTHNWo
# Filtered Hashtags: []
#
# Ek Vivaah Aisa Bhi #jagritipahwa #gopibahu  #youtubepartner #momoslover #indianwedding #couplegoals: https://www.youtube.com/shorts/xmLgvA8VGwM
# Filtered Hashtags: []
#
# Salute to Indian army 😭❤️|| Gulshan kalra #happyrepublicday2022 #shorts: https://www.youtube.com/shorts/t0QtN6kzZBk
# Filtered Hashtags: []
#
# Watch and learn: https://www.youtube.com/shorts/uy8n9izF01k
# Filtered Hashtags: ['Vector', 'Vector TikTok', 'Despicable me TikTok', '@vector', '@_vector_', '_vector_ tiktok', 'Vector nerf tiktok', 'Vector nerf war', 'Vector nerf gun war', 'vector nerf gun', 'vector nerf guns', 'Despicable me tiktok', 'Vector nerf', 'Nerf vector', 'Vector hahaha', 'Vector from tiktok', '_vector_', 'vector despicable me', 'despicable me vector', 'despicable me', 'minions', 'tiktok', 'tiktok trend', 'tiktok newest', 'tiktok compilation', 'best compilation', 'new compilation', 'compilation', 'viral trend', 'nerf', 'funny', 'funny compilation']
#
# कल Sunday है! 😁 | Badi Behen - Choti Behen - Part 35 | #shorts | Shorts Break: https://www.youtube.com/shorts/MFUj-Y9GYQE
# Filtered Hashtags: ['elder sister', 'younger sister', 'elder sister', 'brother sister', 'elder sister vs younger sister aditi sharma', 'sister vs sister', 'sister vs sister', 'younger sister vs elder sister', 'sister sister ka pyaar', 'chhoti sister', 'elder sister vs chhoti sister', 'siblings', 'Maid servant', 'sisters', 'sisters fight', 'siblings squad', 'siblings fight', 'fight', 'aparna tandale', 'sayali sonule', 'school', 'school relatable']
#
# beshak Maut sabko aani he jo bana he wo fanaa he😭🙏🏻 #shorts #emotional #youtubeshorts #short: https://www.youtube.com/shorts/2KDM1qp0_q8
# Filtered Hashtags: []
#
# Try not to laugh (prank edition) #shorts #funny: https://www.youtube.com/shorts/FRdgTgKxnx4
# Filtered Hashtags: []
#
# When a Spider gets inside your Minecraft house (Animated #shorts): https://www.youtube.com/shorts/CtkbksrylwY
# Filtered Hashtags: ['Michazike', 'Witzke', '2d animation', 'animation', 'cartoon', 'cartoon animation', 'minecraft', 'minecraft parody', 'minecraft animation', 'minecraft meme', 'minecraft tiktok', 'tiktok', 'spider on the ceiling', 'minecraft spider', 'spider', 'spider song', 'giant enemy spdier', 'youtube short', 'minecraft short', 'giant spider meme', 'tubbo minecraft', 'tubbo', 'tubbo spider', 'spider dave', 'tubbo spider dave', 'theres a spider on my ceiling and im naming him dave', 'spider dave you better behave', 'tubbo tiktok', 'minecraft funny']
#
# How school is going to be in 2030....😭 | DankScole #shorts: https://www.youtube.com/shorts/AgVr7SBdgq0
# Filtered Hashtags: []
#
# Chalak panipuri wala 😎 #shorts #funny: https://www.youtube.com/shorts/_zgbhnUgEO8
# Filtered Hashtags: []
#
# Candy Chicken #shorts: https://www.youtube.com/shorts/UHjuCdxJQN4
# Filtered Hashtags: []
#
# If babies can Talk 🤣🤣 Maa Bahut Bimar Hai #ytshorts #shorts #AmyraTalks #AmyraTalksEp7: https://www.youtube.com/shorts/FAppBFoRmdY
# Filtered Hashtags: []
#
# Carl Still Remembers Jim [4K Remake] | The Walking Dead #Shorts: https://www.youtube.com/shorts/gyJ8ChsdxTA
# Filtered Hashtags: ['the walking dead', 'twd', 'the walking dead edits', 'twd rick', 'twd rick grimes', 'the walking dead rick', 'the walking dead rick grimes', 'twd carl', 'the walking dead carl', 'the walking dead jim', 'twd carl still remembers jim', 'the walking dead carl still remembers jim', 'twd jim walker', 'twd jim returns', 'the walking dead jim walker']
#
# 👹 😱 bhoot bhago  #shorts: https://www.youtube.com/shorts/Hb21JGmhZeA
# Filtered Hashtags: []
#
# कल Sunday है! 😁 | Badi Behen - Choti Behen - Part 35 | #shorts | Shorts Break: https://www.youtube.com/shorts/MFUj-Y9GYQE
# Filtered Hashtags: ['elder sister', 'younger sister', 'elder sister', 'brother sister', 'elder sister vs younger sister aditi sharma', 'sister vs sister', 'sister vs sister', 'younger sister vs elder sister', 'sister sister ka pyaar', 'chhoti sister', 'elder sister vs chhoti sister', 'siblings', 'Maid servant', 'sisters', 'sisters fight', 'siblings squad', 'siblings fight', 'fight', 'aparna tandale', 'sayali sonule', 'school', 'school relatable']
#
# beshak Maut sabko aani he jo bana he wo fanaa he😭🙏🏻 #shorts #emotional #youtubeshorts #short: https://www.youtube.com/shorts/2KDM1qp0_q8
# Filtered Hashtags: []
#
# Try not to laugh (prank edition) #shorts #funny: https://www.youtube.com/shorts/FRdgTgKxnx4
# Filtered Hashtags: []
#
# When a Spider gets inside your Minecraft house (Animated #shorts): https://www.youtube.com/shorts/CtkbksrylwY
# Filtered Hashtags: ['Michazike', 'Witzke', '2d animation', 'animation', 'cartoon', 'cartoon animation', 'minecraft', 'minecraft parody', 'minecraft animation', 'minecraft meme', 'minecraft tiktok', 'tiktok', 'spider on the ceiling', 'minecraft spider', 'spider', 'spider song', 'giant enemy spdier', 'youtube short', 'minecraft short', 'giant spider meme', 'tubbo minecraft', 'tubbo', 'tubbo spider', 'spider dave', 'tubbo spider dave', 'theres a spider on my ceiling and im naming him dave', 'spider dave you better behave', 'tubbo tiktok', 'minecraft funny']
#
# How school is going to be in 2030....😭 | DankScole #shorts: https://www.youtube.com/shorts/AgVr7SBdgq0
# Filtered Hashtags: []
#
# Chalak panipuri wala 😎 #shorts #funny: https://www.youtube.com/shorts/_zgbhnUgEO8
# Filtered Hashtags: []
#
# Candy Chicken #shorts: https://www.youtube.com/shorts/UHjuCdxJQN4
# Filtered Hashtags: []
#
# If babies can Talk 🤣🤣 Maa Bahut Bimar Hai #ytshorts #shorts #AmyraTalks #AmyraTalksEp7: https://www.youtube.com/shorts/FAppBFoRmdY
# Filtered Hashtags: []
#
# Carl Still Remembers Jim [4K Remake] | The Walking Dead #Shorts: https://www.youtube.com/shorts/gyJ8ChsdxTA
# Filtered Hashtags: ['the walking dead', 'twd', 'the walking dead edits', 'twd rick', 'twd rick grimes', 'the walking dead rick', 'the walking dead rick grimes', 'twd carl', 'the walking dead carl', 'the walking dead jim', 'twd carl still remembers jim', 'the walking dead carl still remembers jim', 'twd jim walker', 'twd jim returns', 'the walking dead jim walker']
#
# 👹 😱 bhoot bhago  #shorts: https://www.youtube.com/shorts/Hb21JGmhZeA
# Filtered Hashtags: []
#
# Mi Hermana Odia el Agua 💧: https://www.youtube.com/shorts/Jd4iHUv1FRk
# Filtered Hashtags: []
#
# SOCIAL MEDIA VS. REALITY (shocking) pt.2  #travel #shorts #socialmedia #reality: https://www.youtube.com/shorts/dqjtA0oE2yU
# Filtered Hashtags: ['social media', 'real life', 'instagram vs reality', 'instagram', 'hiking', 'adrenaline', 'adrenaline junkies', 'winter', 'fortnite', 'world cup', 'bucket list', 'most beautiful places', 'trending', 'tiktok', 'travel', 'travel vlog', 'how to travel', 'reviews', 'travel life', 'travel review', 'world', 'usa travel', 'tiktok 2022', 'beautiful', 'things to see', 'places to visit', 'amazing places', 'travel video', 'christmas markets', 'premier league', 'food', 'fast food', 'food review', 'andrew tate', 'country', 'social media vs reality']
#
# बापरे, इतना मेहेंगा! 😱😂 | Kaamwali Bai - Part 53 | #shorts | Shorts Break: https://www.youtube.com/shorts/Y5NIfbahsHs
# Filtered Hashtags: ['Kaamwali bai', 'Maid servant sheela', 'sheela didi', 'prashant brotherya', 'sayali sonule', 'sayali prashant', 'prashant kulkarni', 'aparna tandale', 'kamwali bai', 'Maid servant comedy', 'sabziyo ki kharidi', 'mehengai comedy', 'itna mehenga', 'sabzi mandi', 'vegetable market', 'Relatable comedy']
#
# Reel Gone Wrong! 😅 | Sisters और Instagram की Reel | #shorts | Shorts Break: https://www.youtube.com/shorts/HyRK6sVirfI
# Filtered Hashtags: ['elder sister', 'younger sister', 'elder sister', 'brother sister', 'elder sister vs younger sister aditi sharma', 'sister vs sister', 'sister vs sister', 'younger sister vs elder sister', 'sister sister ka pyaar', 'chhoti sister', 'elder sister vs chhoti sister', 'siblings', 'Maid servant', 'sisters', 'sisters fight', 'siblings squad', 'siblings fight', 'sibling relation', 'gone wrong comedy', 'fight', 'aparna tandale', 'sayali sonule', 'reel gone wrong', 'reel', 'reels', 'insta reels', 'instagram reels']
#
# Sad story 🥺❤️|| Gulshan kalra #shorts: https://www.youtube.com/shorts/XVIuiqJ6b98
# Filtered Hashtags: []
#
# POV: A queen finally breaks the generational cycle...: https://www.youtube.com/shorts/mayhQW1qOT4
# Filtered Hashtags: ['POV', 'acting', 'stories', 'tiktok', 'POV creators', 'Jessica Kaylee', 'thumbs', 'queen', 'princess', 'princess pov', 'mother has a daughter', 'generation', 'music', 'lip sing', 'trend', 'viral']
#
# Random Black food MUKBANG💀 #shorts: https://www.youtube.com/shorts/wAYrfNdGq2s
# Filtered Hashtags: []
#
# Respect shorts #shorts 😍💯🔥💯😍: https://www.youtube.com/shorts/yi6qn7bbT4c
# Filtered Hashtags: []
#
# Pyaar karo toh aise karo😅❤️#shorts #unknownboyvarun: https://www.youtube.com/shorts/YtYkAG8Pp_k
# Filtered Hashtags: []
#
# 0 đồng ăn gì? p80 #shorts #tiktok #foryou #xuhuong #fyp #langlieu: https://www.youtube.com/shorts/wC0adVz8VTs
# Filtered Hashtags: ['tiktok', 'tik tok ẩm thực', 'ẩm thực', '1 đồng mua được gì', 'một đồng mua được gì', 'ẩm thực trung quốc', 'spicy food', '1 dong mua duoc gi', 'am thuc trung quoc', 'tik tok 1 dong', 'tik tok china', 'tik tok', 'lang lieu tiktok', '1 đồng', '1 tệ', 'mot dong mua duoc gi', 'lang lieu', 'chinese food', 'ẩm thực 1 đồng', '1 dong', '1 xu', 'cuisine', '1 đồng ăn gì', 'what can $1 buy', 'spicy food challenge', 'khana', 'hot pot', '1 dong an gi', '$1 can buy anything', 'extreme spicy food', 'tiktok triệu view', 'tiktok 2023']
#
# Harami Student Se Panga 😂-#funnyvideo #funny ￼#shorts: https://www.youtube.com/shorts/j4vD2pvK5_E
# Filtered Hashtags: []
#
# maa or beti ka rishta😓😥😥| The geeta gurjar #shorts #viral #youtubeshorts #trending: https://www.youtube.com/shorts/--5AroB3O3Q
# Filtered Hashtags: []
#
# Sir ka chakkr😂🤘🏻|| Jaanvi patel #shorts: https://www.youtube.com/shorts/5cuQEGB-W30
# Filtered Hashtags: []
#
# handmade highlighter / handmade coloring pen #shorts #tonniartandcraft #youtubeshorts: https://www.youtube.com/shorts/IAaR8MxeGFw
# Filtered Hashtags: []
#
# Bhai behen ki ladai ❤️😂part - 7 #shorts  #jaanvipatel  || Jaanvi patel: https://www.youtube.com/shorts/D9wFSUigvwI
# Filtered Hashtags: []
#
# Teacher Vs Harami student 😂-#funnyvideo #funny #shots: https://www.youtube.com/shorts/HsJ5PzehTW4
# Filtered Hashtags: []
#
# Ye kitne gande h meko fir ullu bna diya 🥺🙏🏻 #youtubeshort #youtube #shortvideo @chotanawab: https://www.youtube.com/shorts/JRF-kMTSK3c
# Filtered Hashtags: []
#
# Front Seat पे किसे बिठाऊ 😂 | #shorts | Shorts Break: https://www.youtube.com/shorts/hsk-5-sM2w0
# Filtered Hashtags: ['gf vs bf', 'gf vs bf comedy', 'gf bf comedy', 'gf bf comedy video', 'gf bf', 'gf vs bf new comedy', 'gf vs bf new comedy video', 'gf bf funny status', 'how to end an argument with wife', 'comedy shorts', 'shorts break comedy', 'Maid servant', 'toxic relationship', 'gf', 'bf', 'girlfriend', 'boyfriend', 'desi gf', 'goes wrong comedy', 'aparna tandale', 'shashank swamod', 'chiku chikki', 'best friend', 'dost', 'friend', 'girl best friend']
#
# Potato chips #shorts: https://www.youtube.com/shorts/ey9w0UetIUA
# Filtered Hashtags: []
#
# Share with such Sneakers Heads 😂 #Shorts #Funcho: https://www.youtube.com/shorts/tVf4UoVdOso
# Filtered Hashtags: []
#
# seeing wife face for first time #shorts: https://www.youtube.com/shorts/4TSHzi94Qb0
# Filtered Hashtags: ['drama', 'funny', 'prank', 'skit', 'viral']
#
# Family love story #surajactor: https://www.youtube.com/shorts/2UEZzzcuUX8
# Filtered Hashtags: ['Surajactor new shorts', 'Surajactor trending video', 'Surajactor viral video', 'Surajactor or priti ka video', 'Surajactor ka nya wala video', 'Surajactor or priti ka family shorts', 'YouTube', 'Surajactor', 'Surajrajput insta video']
#
# लड़के कभी घर का काम नहीं कर सकते😂 #youtubeshorts #love #funnyvideo #comedy #hellobrother: https://www.youtube.com/shorts/WSJtYd6071U
# Filtered Hashtags: []
#
# Tom 🍓 Jerry (Rithvi&amp;Kavi) Real End Twist 😂🎈 #shorts: https://www.youtube.com/shorts/sPFpkN1uw08
# Filtered Hashtags: []
#
# achha beta wahi jo baap ki feeling samjhe😭🙏🏻 #shorts #emotional #youtubeshorts #viral #short: https://www.youtube.com/shorts/CQly9VeFWp4
# Filtered Hashtags: []
#
# Kya popat banaya hai yrr🤣❤️ #unknownboyvarun: https://www.youtube.com/shorts/pTA3cPCAb7I
# Filtered Hashtags: []
#
# Jaisi Karni Waisi Bharni 🤣- #funnyvideo #shots #funny: https://www.youtube.com/shorts/H755rIGtKg4
# Filtered Hashtags: []
#
# The Bare Necessities Of Calzone Making!🤤 #shorts #webarebears #calzone #cartoonnetwork: https://www.youtube.com/shorts/CE9UdrlhMLM
# Filtered Hashtags: ['we bare bears', 'we bare bears cartoon network', 'cartoon network we bare bears', 'we bear bears', 'bare bears', 'the bare bears', 'bears', 'we bare bear', 'we baer baers', 'we bare bears food', 'we bare bears full episodes', 'bare bear', 'bears bears bears', 'we bare bears show', 'we bare bears thailand', 'we bear bear', 'we bare bears full episode', 'calzone we bare bears', 'we bear', 'calzone', 'we bare bears clip', 'we bare bears clips', 'we bare bears hindi', 'we bare bears sneak peek', 'we bare bears mashup']
#
# Black Witch Returns 😈 (Trailer) #priyalkukreja #shorts: https://www.youtube.com/shorts/YpMSjZpkylY
# Filtered Hashtags: ['Viral', 'Comedy', 'Funny', 'Tiktok', 'Trending', 'Instagram reels', 'Priyal kukreja', 'Dushyant kukreja', 'Priyal kukreja shorts', 'Dushyant kukreja shorts', 'Ytshorts', 'Siblings comedy', 'Brother sister comedy', 'Whatsapp status', 'Trending shorts', 'Black Witch series', 'Black witch returns', 'Black with returns trailer']
#
# Sister VS Me  |  Types Of  Maggi Eating 😜😂 #minkutinku #shorts #comedy #funny #ashortaday  #maggi: https://www.youtube.com/shorts/G5pOo72QS8w
# Filtered Hashtags: ['#comedy', '#funny', '#funnyvideo', '#comedyvideo', '#viralvideo', '#ytshorts', '#youtubeshorts', '#shortvideo', '#trending', '#trendingshorts', '#viral', '#Dushyant_kukreja', '#bihariladka', '#rjkarishma2859', '#Chimkandi', '#Priyal Kukreja', '@ChetanMongaVlogs', '@salonayyy', '#WonderMunnaShorts', 'comedy', 'funny', '#tmkoc', '#TMKOC', '@spider-maaaaaaan', 'youtube', '#yt', 'Jethalal Gada', '#Jethalal', 'Sush & Yohan', '#indian', '#india', '#maa', 'Fight for Maggi', '#golgappa', '#TheVishalbhatt', '#ChetanMongaVlogs', '#TheMermaidscales', '#MabuCrush', 'Types Of Friends In School']
#
# Dance teacher ❤️😍 #shorts  || Jaanvi patel || #nazneen #sagamusic #uchanaamit #newhindisong2022: https://www.youtube.com/shorts/g_4zg4Oiwwo
# Filtered Hashtags: []
#
# Cute baby enjoying in slide 🛝 #viral #shorts #youtubeshorts #aarorakhadka: https://www.youtube.com/shorts/39Jq2Pgn4R0
# Filtered Hashtags: []
#
# Mirchi wale panipuri🌶️🥵wait for end🤣🤣 #comedy #revenge #funny #shorts: https://www.youtube.com/shorts/cTUHdEnpA3s
# Filtered Hashtags: []
#
# Ye Kya kar diya🤬💔🤣#comedy #funny #viral #tiktok: https://www.youtube.com/shorts/no7ruYg9aHs
# Filtered Hashtags: []
#
# Girls School: https://www.youtube.com/shorts/WUW34aKDcZs
# Filtered Hashtags: ['The paayal jain', 'Paayal jain', 'Tena jaiin', 'Payal', 'Paayal tena', 'Paayal tena short videos', 'Paayal tena shorts', 'Payal tina', 'Comedy videos', 'Comedy shorts', 'Funny videos', 'Funny shorts', 'School', 'School life', 'School days', 'School girls', 'School girl', 'School friends', 'Farewell', 'Girls school', 'Girls', 'School farewell', '12th farewell', 'Farewell party', 'Farewell saree', 'School exams', 'Exams', 'Exam days', 'Exam', 'Girls farewell', 'Every', 'Ever', 'Every girls school']
#
# पहले Cake किसे खिलाऊ 😂 | #shorts | Shorts Break: https://www.youtube.com/shorts/o0NyyPnSMLA
# Filtered Hashtags: ['gf vs bf', 'gf vs bf comedy', 'gf bf comedy', 'gf bf comedy video', 'gf bf', 'gf vs bf new comedy', 'gf vs bf new comedy video', 'gf bf funny status', 'how to end an argument with wife', 'comedy shorts', 'shorts break comedy', 'Maid servant', 'toxic relationship', 'gf', 'bf', 'girlfriend', 'boyfriend', 'desi gf', 'goes wrong comedy', 'aparna tandale', 'shashank swamod', 'chiku chikki', 'best friend', 'dost', 'friend', 'girl best friend']
#
# Junk Food vs Homemade Food 😋 #sabgazab #goldkartz #badboyshah #trending: https://www.youtube.com/shorts/Ozz70IQa-Mk
# Filtered Hashtags: ['Viral', 'Comedy', 'Funny', 'Tiktok', 'Trending', 'Instagram reels', 'Priyal kukreja', 'Dushyant kukreja', 'Priyal kukreja shorts', 'Dushyant kukreja shorts', 'Ytshorts', 'Siblings comedy', 'Brother sister comedy', 'Whatsapp status', 'Trending shorts', 'Youtube shorts', 'Youtube trending', 'Junk food vs Homemade food']
#
# 🔥Tripping Over Nothing Prank 🤣 #comedy #funny #pranks: https://www.youtube.com/shorts/bZdpihF44R0
# Filtered Hashtags: ['prank', 'joke', 'laugh', 'funny', 'new prank']
#
# Aapke dost aapko kya bolte h comment me zaroor likhna😂❤️|| Gulshan kalra #shorts: https://www.youtube.com/shorts/v2ZIXERCblQ
# Filtered Hashtags: []
#
# गलतियों का Scoreboard 😆 | Husband Vs. Wife - Part 31 | #shorts | Shorts Break: https://www.youtube.com/shorts/pBMOoJm9Nqc
# Filtered Hashtags: ['husband vs wife', 'husband', 'wife', 'husband wife comedy', 'husband and wife comedy', 'husband vs wife fight', 'husband vs wife comedy', 'Maid servant', 'brotheryya', 'husband and wife', 'husband wife fight', 'husband wife jokes', 'husband and wife comedy shorts', 'husband wife relationship', 'husband wife jokes in hindi', 'Maid servant sheela comedy', 'prashant', 'sayali', 'sayali sonule', 'prashant brotherya']
#
# kya setaan baccha he yrr😢😂 #shorts #youtubeshorts #viral #emotional #short: https://www.youtube.com/shorts/LJbOn3w7nVU
# Filtered Hashtags: []
#
# How to transform your old clothes on a budget 😎 #howto #5minutecrafts #hack #diy: https://www.youtube.com/shorts/YbU87KMkWlU
# Filtered Hashtags: []
#
# Cute love story 🥺❤️ #shorts  || Jaanvi patel ||: https://www.youtube.com/shorts/todN3UAp4FY
# Filtered Hashtags: []
#
# माँ बेटा और चोर पुलिस 🤣 |  Maa Beta | #shorts | Shorts Break: https://www.youtube.com/shorts/jKRRlJjqFuw
# Filtered Hashtags: ['comedy shorts', 'shorts break comedy', 'short break channel', 'take a break', 'maa beta funny video', 'maa beta comedy', 'maa beta comedy video', 'maa aur beta comedy', 'maa aur nalayak beta comedy', 'maa bete ka comedy', 'maa beta', 'mom', 'mother', 'mom vs me', 'mami and mi', 'me vs mom', 'my mom', 'types of mom', 'family comedy', 'shashank swamod', 'sayali sonule', 'savage mom', 'relatable', 'relatable shorts']
#
# Cutest Love Story😍❤️ #unknownboyvarun: https://www.youtube.com/shorts/6Jnx7pFTCiI
# Filtered Hashtags: []
#
# Dost ki bezzati ka badla 😂😎 #shorts  #foryou #schoollife: https://www.youtube.com/shorts/ymQiv4INTJ8
# Filtered Hashtags: []
#
# Food at Weddings 🤩 #priyalkukreja #shorts #ytshorts: https://www.youtube.com/shorts/YUUXa4toC4Q
# Filtered Hashtags: ['Viral', 'Comedy', 'Funny', 'Tiktok', 'Trending', 'Instagram reels', 'Priyal kukreja', 'Dushyant kukreja', 'Priyal kukreja shorts', 'Dushyant kukreja shorts', 'Ytshorts', 'Siblings comedy', 'Brother sister comedy', 'Whatsapp status', 'Trending shorts', 'Youtube shorts', 'Food at weddings', 'Wedding comedy']
#
# End tak zaroor dekhna😍❤️|| @unknownboyvarun ||Gulshan kalra #shorts: https://www.youtube.com/shorts/Oz4msYqlpmk
# Filtered Hashtags: []
#
# Sigma Kid And Bad Boy😂👻❤️ #shorts: https://www.youtube.com/shorts/Mpg-lVy5zHM
# Filtered Hashtags: []
#
# शीला दीदी हवा में उड़ जाएगी 😂 | Kaamwali Bai - Part 67 | #shorts | Shorts Break: https://www.youtube.com/shorts/pq290DPLxA8
# Filtered Hashtags: ['Kaamwali bai', 'Maid servant sheela', 'sheela didi', 'prashant brotherya', 'sayali sonule', 'sayali prashant', 'prashant kulkarni', 'aparna tandale', 'kamwali bai', 'Maid servant comedy', 'lottery comedy', 'Maid servant', 'shila ki comedy', 'types of Maid servant', 'funny Maid servant', 'kaam wali bai series', 'kamwali bai shila', 'kamwali bai short', 'कामवाली बाई', '#कामवाली बाई शॉर्टस', 'sheela didi comedy']
#
# I replayed this video 100 times😱: https://www.youtube.com/shorts/OiDOMNlnpZY
# Filtered Hashtags: []
#
# O Re Piya Singing Challenge 😆 | #shorts | Wait For It: https://www.youtube.com/shorts/eVMjLW_Yhyg
# Filtered Hashtags: ['challenge', 'fun challenge', 'party games', 'games', 'fun games', 'challenge shorts', 'fun shorts', 'games shorts', 'challenges', 'wait for it', 'wait for it shorts', 'desi challenges', 'desi challenges shorts', 'wfi', 'new challenge', 'comedy challenges', 'o re piya singing challenges', 'singing challenge', 'wait for it singing', 'wait for it singing challenges', 're piya singing challenge', 'o re piya', 'viral singing challenge', 'funny singing challenge', 'o re piya song', 'ore piya singing challange', 'ore piya']
#
# #grwm for a movie #shorts: https://www.youtube.com/shorts/TssqS-yNxks
# Filtered Hashtags: []
#
# Burro de Chilaquiles con @domelipa 🌯🍭: https://www.youtube.com/shorts/V9_OUlEmS9o
# Filtered Hashtags: []
#
# Tom 🍓 Jerry (Rithvi&amp;Kavi)Real End Twist 😂🎈 #shorts: https://www.youtube.com/shorts/D2i-hMcNOBA
# Filtered Hashtags: []
#
# #POV bring peace by ending cycle of generational corruption #shorts #acting #youtubeshorts #viral: https://www.youtube.com/shorts/VDIinAkq-j8
# Filtered Hashtags: []
#
# End miss mat karna😂❤️|| Gulshan kalra #shorts: https://www.youtube.com/shorts/L5AYVQvzkZ8
# Filtered Hashtags: []
#
# Hand Pump Tod diya | sweets buy kiya | mini vlog - 29 #shorts: https://www.youtube.com/shorts/wurkM9HJWh8
# Filtered Hashtags: []
#
# Childhood friendship story 👫❤️ #shorts #jaanvipatel | Jaanvi Patel|: https://www.youtube.com/shorts/0-N--EEd_5Q
# Filtered Hashtags: []
#
# मेरी Bag! 😂 | Badi Behen - Choti Behen - Part 34 | #shorts | Shorts Break: https://www.youtube.com/shorts/ifBpGFq62fs
# Filtered Hashtags: ['elder sister', 'younger sister', 'elder sister', 'brother sister', 'elder sister vs younger sister aditi sharma', 'sister vs sister', 'sister vs sister', 'younger sister vs elder sister', 'sister sister ka pyaar', 'chhoti sister', 'elder sister vs chhoti sister', 'siblings', 'Maid servant', 'sisters', 'sisters fight', 'siblings squad', 'siblings fight', 'gone wrong comedy', 'fight', 'aparna tandale', 'sayali sonule']
#
# Cute girl ☺️: https://www.youtube.com/shorts/WNVz7N41u_I
# Filtered Hashtags: []
#
# Saccha pyar humesha dard deta hai🥺❤️ #shorts: https://www.youtube.com/shorts/DOFacuWr-MY
# Filtered Hashtags: []
#
# Sisters और Face Pack 😂😉 | Badi Behen Choti Behen - Part 26 | #Shorts | Shorts Break: https://www.youtube.com/shorts/daDYSk1r5ZU
# Filtered Hashtags: ['elder sister', 'younger sister', 'elder sister', 'sister hogi teri', 'brother sister', 'best friends', 'elder sister vs younger sister aditi sharma', 'sister vs sister', 'sister vs sister', 'younger sister vs elder sister', 'sister sister ka pyaar', 'chhoti sister', 'elder sister vs chhoti sister', 'siblings', 'Maid servant', 'sisters', 'sisters fight', 'siblings squad', 'siblings fight', 'sibling relation', 'gone wrong comedy', 'fight', 'aparna tandale', 'sayali sonule']
#
# ACNE PHONE CASE 📱 ADORABLE CLEANING by 123GO! Reacts #shorts: https://www.youtube.com/shorts/vr3IpTR6sy8
# Filtered Hashtags: ['123 go', '123 go shorts', '123 go!', '123 go! reacts', '123 go! shorts', '123go', '123go!', '123go!reacts', '5 minute crafts', 'comedy video', 'craft', 'crafts', 'diy', 'do it yourself', 'friend', 'friendly', 'friends', 'fun', 'funny', 'funny reaction', 'hack', 'hacks', 'how to', 'howto', 'humor', 'humor video', 'life hack', 'life hacks', 'lifehacks', 'pranks', 'react', 'reaction', 'role play', 'short video', 'short videos', 'shorts india', 'shorts usa', 'tik tok', 'tiktok', 'trick', 'tricks', 'troom troom', 'try not to laugh', 'tutorial']
#
# ...
#
# Nachde Ne Saare 😍 #neetubisht #trending #wedding #trendingonshorts #shorts: https://www.youtube.com/shorts/cf6NJDdvjxI
# Filtered Hashtags: []
#
# ¿POR QUÉ HAY ENDERMANS EN EL END? #minecraft #minecraftshorts #shorts: https://www.youtube.com/shorts/rNMmZ2oYEqA
# Filtered Hashtags: []
#
# SECRETÁRIA DE CONSULTÓRIO - bárbara coura #shorts: https://www.youtube.com/shorts/Iwg9qd-A3Hg
# Filtered Hashtags: []
#
# 10 velu kaavala 😂😂 #prashucomedy #funny #telugucomedy #prashubaby #shorts: https://www.youtube.com/shorts/EBYVgWbU9PQ
# Filtered Hashtags: []
#
# Random Amazon Find!🥤 #stanley #shorts #shortscreator #stanleycup #stanleytumbler: https://www.youtube.com/shorts/3yvJgRysi28
# Filtered Hashtags: []
#
# Qual nota de 0 a 10 esse vídeo merece? 😮 Comenta aí #dance #shorts: https://www.youtube.com/shorts/2sv2f4wRv6A
# Filtered Hashtags: []
#
# ALMOÇANDO SHORTS PT.23 #shorts: https://www.youtube.com/shorts/DNx1Adxzz7s
# Filtered Hashtags: []
#
# Jaadui perfume 😨 | jaanvi patel #shorts: https://www.youtube.com/shorts/AXoQe5tBsG4
# Filtered Hashtags: []
#
# Mi GATITA BEBÉ escoge con cuál DECORACIÓN me quedo😺😍 #shorts: https://www.youtube.com/shorts/JhOiIZsIyco
# Filtered Hashtags: ['ani cat', 'ana vallee', 'anica', 'ani videos', 'pop it', 'pop its', 'tradeo pop it', 'probando pop its', 'asmr pop it', 'miraculous', 'comedia', 'shorts de comedia', 'shorts de pop it', 'escogiendo pop its', 'juguetes antiestres', 'pop it o slime', 'eslaim', 'videos de eslaim', 'videos de pop it', 'figuritas antiestres', 'estilo kawaii', 'que escoges tu', 'funko pop', 'funkos', 'escoge tu funko pop', 'Escoge CUÁL REGALO te quedas y cuál ABANDONAS', 'utiles escolares', 'utiles kawaii', 'cosas kawaii', 'la chica de los plumones']
#
# Kannst du die Stimme zuordnen? 😂🎤 #916house #916shorts #shorts: https://www.youtube.com/shorts/5aQKIK49ntc
# Filtered Hashtags: []
#
# Ну почему? По кочану! Песня в minecraft! 🤣: https://www.youtube.com/shorts/pGZu85EVxhc
# Filtered Hashtags: ['майнкрафт', 'почему по кочану', 'ну почему по кочану', 'почему', 'по кочану', 'minecraft', 'minecraft песня', 'песня minecraft', 'shorts minecraft', 'shorts майнкрафт', 'майнкрафт шортс', 'шортс minecraft', 'minecraft shorts', 'minecraft шортс', 'шортс', 'titwow', 'титмаус', 'песня', 'почему по качану']
#
# Letter Challenge 😂 Funny Malayalam challenge #shorts #short: https://www.youtube.com/shorts/gK2bMK2ZALw
# Filtered Hashtags: []
#
# Ronaldo😱🥶😱 #shorts #ronaldo #messi #shortsvideo: https://www.youtube.com/shorts/kIwPL0OLB7k
# Filtered Hashtags: []
#
# A perseguição (parte 2) - Duda Maryah #shorts: https://www.youtube.com/shorts/bZZZjS1qDQM
# Filtered Hashtags: []
#
# FNAF cake vs Jelly ice cream challenge!🍨 #funny #shorts by Ethan Funny Family: https://www.youtube.com/shorts/cxUKfYOeYM8
# Filtered Hashtags: []
#
# Probé el cereal de la Novia de Chucky 🤤 #shorts: https://www.youtube.com/shorts/dZFRHEkhTxs
# Filtered Hashtags: []
#
# Inter nibbi part 33 | ashok vibes | Telugu comedy shorts | like and subscribe #comedy #girls: https://www.youtube.com/shorts/l970Szsl1SM
# Filtered Hashtags: []
#
# Cook with me at 1AM #minivlog #ytshorts #shorts #trending: https://www.youtube.com/shorts/-o8VH-cSv7I
# Filtered Hashtags: []
#
# GRWM for sister Roka🥳 | Anju Mot | #trendingonshorts #grwm #shorts #shopwithyoutube: https://www.youtube.com/shorts/68gpjfCrEnw
# Filtered Hashtags: ['anju mor', 'Anjumordance', 'maskara', 'mskara', 'mascara', 'GRWM', 'trending on short']
#
# Kotha Janta Part-160 #Shorts #PravallikaRichhakka: https://www.youtube.com/shorts/xQvgfy003Iw
# Filtered Hashtags: ['Rich akka', 'Rich aunty', 'rich akka daughter', 'rich akka daughter suviksha', 'suviksha reels', 'suviksha shorts', 'suviksha videos', 'suviksha vlogs', 'emotional', 'sad', 'sentiment', 'relationship', 'family', 'atha kodallu', 'comedy', 'hilarious', 'humour', 'Telugu comedy videos', 'funny videos', 'rich akka pravallika', 'pravallika shorts', 'pravallika YouTube shorts', 'trending videos', 'Suvvy', 'suviksha sindhu videos', 'rich akka shorts']
#
# Padosiyo ne chori karte pakda🫢 / Easy diy hair pin /  ghamu saran #shorts #diy: https://www.youtube.com/shorts/r9YRofb282Y
# Filtered Hashtags: ['handmade', 'cap hairpin', 'doll', 'cap', 'barbie', 'hat', 'at', 'home', 'ghamu', 'saran', 'viral', 'diy', 'ideas', 'divya', 'yt']
#
# Siblings Challenge🤣 Part-194😂 #shorts #shortsvideo #shortsfeed #youtubeshorts #challenge #viral: https://www.youtube.com/shorts/dZFX1kwAuro
# Filtered Hashtags: []
#
# Birthday party…..🎂 #payalpanchal #minivlog #shorts: https://www.youtube.com/shorts/MLAAFDQ9xGw
# Filtered Hashtags: []
#
# Sugar apple Kulfi #shorts: https://www.youtube.com/shorts/vRXrdDIMGqw
# Filtered Hashtags: []
#
# #POV you meet the sister elements of Christmas ❄️🔥#shorts #fantasy #acting: https://www.youtube.com/shorts/QePAep8OlVI
# Filtered Hashtags: []
#
# Mini Vlog 21 - Shilp Mela😱 #crafteraditi #minivlog #shorts #dayinthelife @CrafterAditi: https://www.youtube.com/shorts/6DRI4JFMHq0
# Filtered Hashtags: []
#
# Don’t Play Baja Challenge 😂 #shorts: https://www.youtube.com/shorts/kFUjH2Ndw8o
# Filtered Hashtags: []
#
# BOCIL BISA MELIHAT HANTU ?! | Klara Tania #shorts: https://www.youtube.com/shorts/Jv2gO3woVKc
# Filtered Hashtags: []
#
# QUIZ UPIN IPIN DADAKAN WKWKWKW UNTUNG BNER SMUA 🗿😤 #shorts #itsmeissie: https://www.youtube.com/shorts/VuCdY18-15w
# Filtered Hashtags: []
#
# Trying Out Unique Fire Pizza in Delhi | Ye kya aag laga di bhai😅😅 @cravingsandcaloriesvlogs #shorts: https://www.youtube.com/shorts/Wkb67OBnd-Q
# Filtered Hashtags: ['cravings and calories shorts', 'cravings and calories', 'delhi food blogger', 'fire pizza in delhi', 'unique fire pizza', 'farzi cafe delhi', 'farzi cafe delhi menu', 'trying out fire pizza', 'taste test pizza', 'tasting the unique fire pizza', 'trying out unique fire pizza in delhi', 'trying out farzi cafe menu', 'farzi cafe food review', 'farzi cafe delhi food review', 'basket cheese cake', 'indian cuisine', 'farzi cafe honest food review', 'honest food review', 'unique fire pizza honest food review']
#
# Iphone 15 Pro max Chaiye?😂apke pas konsa phone hai?😁 Salman Noman❤️ #shorts #holidayswithshorts: https://www.youtube.com/shorts/DjENa5dmHMo
# Filtered Hashtags: []
#
# White parents Vs African parents when a child falls down 😹 #shorts: https://www.youtube.com/shorts/V9J_atE6Q-k
# Filtered Hashtags: ['Relatable', 'funny', 'funny videos', 'African parents', 'American parents Vs African parents']
#
# Tá com fome Luluca ? #shorts #luluca: https://www.youtube.com/shorts/FyoDQbHXnxo
# Filtered Hashtags: []
#
# Hãy cảnh giác với tội phạm mua bán người #shorts  #trithucplus #trithuc: https://www.youtube.com/shorts/W1LWZ4zGsm4
# Filtered Hashtags: ['tri thức +', 'tri thức plus', 'kiến thức', 'kiến thức thú vị', 'sự thật', 'sự thật khó tin', 'khám phá', 'facts', 'có thể bạn chưa biết', 'biết thêm mỗi ngày', 'biết thêm một chút', 'sự thật thú vị', 'Hãy cảnh giác với tội phạm mua bán người', 'Cảnh giác trước cạm bẫy của các đối tượng buôn bán người', 'Tội phạm mua bán người', 'Cảnh giác với các thủ đoạn mua bán người', 'Cảnh giác với hoạt động mua bán người', 'Tội phạm buôn người không từ thủ đoạn nào', 'Chiêu trò buôn người']
#
# COMO ACHAR A PONTA DA FITA!!! #shorts: https://www.youtube.com/shorts/qMymrgdSFTE
# Filtered Hashtags: []
#
# Attempting a Spartan race 3 months postpartum #shorts: https://www.youtube.com/shorts/bD38uSiM_jM
# Filtered Hashtags: []
#
# 떡볶이 먹은 이재용의 반응은? / 채널A #shorts: https://www.youtube.com/shorts/l_4F17E4Qrk
# Filtered Hashtags: []
#
# HADUHH MAU GA LANJUT PRAT 2 NYA? WKWKWKW 😭🤣 #shorts #itsmeissie #lol #filter: https://www.youtube.com/shorts/Qxy6BRm82Lc
# Filtered Hashtags: []
#
# Gutka lovers in winter 🥶🔥| indian family #shorts #indian #relatable #gutkasong: https://www.youtube.com/shorts/Wn02YsgflTA
# Filtered Hashtags: []
#
# Everything is Awesome in LEGO Fortnite!: https://www.youtube.com/shorts/_1ASvkI9Ld4
# Filtered Hashtags: ['Fortnite shorts', 'YouTube shorts', 'dagwummy', 'LEGO Fortnite', 'lego fortnite skins', 'lego fortnite mode', 'lego fortnite survival', 'lego fortnite sandbox', 'lego fortnite sets', 'lego fortnite world', 'lego fortnite skeletons', 'lego fortnite mobs', 'lego fortnite tips', 'lego fortnite tutorial', 'Fortnite is minecraft', 'lego fortnite multiplayer']
#
# TENDRE UNA PELEA DE BOX?😱ADIVINA CONTRA QUIEN SERA #shorts: https://www.youtube.com/shorts/FAnRSiD7H3Y
# Filtered Hashtags: []
#
# ESTO OPINA YO SOY PAU DEL SHIP DE ALLISON Y LUIGI, EL NUEVO DISCO DE KIM Y NASYA BUSTILLOS #shorts: https://www.youtube.com/shorts/TPE3nRSlrao
# Filtered Hashtags: []
#
# HAMBÚRGUER GIGANTE DE GELATINA! #shorts: https://www.youtube.com/shorts/DuHTyZVWSw8
# Filtered Hashtags: []
#
# Ye gajab ka baking paper hai😱3-4 times use Kiya #shorts #shortsfeed #viral #trending #cake #youtube: https://www.youtube.com/shorts/G8WCsz9gWEs
# Filtered Hashtags: ['Best baking paper', 'Ecobake paper review', 'How to make cake at home', 'Cake kaise bnate hain', 'Cake bnane ka ashan tareeka', 'Satisfying cake decoration', 'Soumya c recipes new video', 'Soumya c recipes new shorts', 'Homemade cake design', 'Treading cake', 'Bakery style cake decoration', 'Birthday cake design', 'Cake decorating compilation', 'Cake decoration shorts', 'Easy cake design', 'Viral cake video', 'YouTube shorts', 'Cake video']
#
# KITA BUKA KADO BUAT KARAKTER POV KU YUK #POV #shorts: https://www.youtube.com/shorts/iSayD9Eb1rA
# Filtered Hashtags: ['kt', 'kta', 'bka', 'bk', 'kdo', 'kd', 'bt', 'krakter', 'yu', 'yok']
#
# Tipos de personas haciendo la CARTA a SANTA CLAUS🎅🎄 #shorts: https://www.youtube.com/shorts/Hq3_bq7YaSs
# Filtered Hashtags: ['ani cat', 'ana vallee', 'anica', 'ani videos', 'navidad shorts', 'Cuando ABRES los REGALOS de NAVIDAD', 'El mejor regalo de Navidad', 'Cosas que puedes pedir para navidad', 'navidad navidad dulce navidad', 'navidad canciones', 'shorts de navidad', 'arbolitos de navidad', 'mejores regalos de navidad', 'videos de Santa Claus', 'navidad navidad hoy es navidad', 'tipos de personas haciendole la carta a santa', 'carta a santa', 'tipos de personas en navidad', 'tipos de personas abriendo regalos', 'abriendo regalos']
#
# Joy Baba Bholenath🙏🙏🙏#Kritikachannel#Shorts video: https://www.youtube.com/shorts/M-dLM5tJUJ4
# Filtered Hashtags: []
#
# LGBT short film &quot;Flamingo Pride&quot; | by Tomer Eshed: https://www.youtube.com/shorts/vojEWV13BQc
# Filtered Hashtags: ['Short film', 'Kurzfilm', 'Kurzfilm Festival', 'shorts festival', 'animation', 'court-métrage', 'court métrage', '3D', 'funny', 'humour', 'drôle', 'lustig', 'Tomer Eshed', 'HFF Konrad Wolf', 'HFF Potsdam-Babelsberg', 'flamant rose', 'gay', 'Liebe', 'amour', 'Love', 'gay pride', 'cigogne', 'stork', 'Storch', 'homo', 'straight', 'PLAY_ANI', 'PLAY_FUN']
#
# Kotha Janta Part-159 #Shorts #PravallikaRichhakka: https://www.youtube.com/shorts/plv6PsPXdLY
# Filtered Hashtags: ['Rich akka', 'Rich aunty', 'rich akka daughter suviksha', 'suviksha reels', 'suviksha shorts', 'suviksha YouTube videos', 'suviksha vlogs', 'pravallika rich akka Kotha janta', 'Kotha janta suviksha', 'rich akka Kotha janta', 'rich akka pravallika', 'emotional', 'newly married', 'couple', 'sentiment', 'sad', 'relationship', 'atha kodallu', 'comedy', 'hilarious', 'humour', 'Telugu comedy videos', 'trending shorts', 'Pravallika YouTube channel', 'pravallika rich', 'Sindhu']
#
# It’s my birthday cake 🥰 #shorts #shortsfeed #viral #trending #cake #youtube #baking #homebaker: https://www.youtube.com/shorts/uDWCouO8Q4w
# Filtered Hashtags: ['Cake decorating ideas', 'Easy cake decoration', 'How to make cake at home', 'Cake kaise bnate hain', 'Cake bnane ka ashan tareeka', 'Soumya c recipes cake video', 'Soumya c recipes new shorts', 'Birthday cake decoration', 'Homemade cake decoration', 'Homebakers cake', 'Bakery style cake decoration', 'Bakery style cake', 'Cake decorating compilation', 'Cake decoration shorts', 'Trending shorts', 'YouTube shorts']
#
# Wait for end ✨🤩✨ #comedy #comedyvideo #shorts #youtubeshorts #funny #funnyvideo: https://www.youtube.com/shorts/6cFuXqoIL9w
# Filtered Hashtags: ['yt shorts', 'shorts video', 'telugu comedy videos', 'funny telugu videos', 'comedy videos', 'funny comedy videos']
#
# Pecado: Pereza 🦥 | Nunca tienes ganas de hacer algo | POV | SHORT | Ivanova BM | #shorts #viral: https://www.youtube.com/shorts/wr-tOadh8sM
# Filtered Hashtags: []
#
# PESTA ULANG TAHUN - TIFFABELLE HOROR #POV #shorts #horrorstories: https://www.youtube.com/shorts/oF-tXdSMIKg
# Filtered Hashtags: ['psta', 'pst', 'ulng', 'thun', 'thn']
#
# BALA CESTA DE BASQUETE! #shorts: https://www.youtube.com/shorts/mMWCUbtFiyA
# Filtered Hashtags: []
#
# Life Update 🥹❣️ | #231 | #shorts #minivlog #HolidaysWithShorts: https://www.youtube.com/shorts/w79hmdmNOLs
# Filtered Hashtags: []
#
# I will play guitar today 🎸😎 #priyalkukreja #shorts #ytshorts: https://www.youtube.com/shorts/cWQklmeAooE
# Filtered Hashtags: ['Viral', 'Comedy', 'Funny', 'Tiktok', 'Trending', 'Instagram reels', 'Priyal kukreja', 'Dushyant kukreja', 'Priyal kukreja shorts', 'Dushyant kukreja shorts', 'Ytshorts', 'Siblings comedy', 'Brother sister comedy', 'Whatsapp status', 'Trending shorts', 'Youtube shorts', 'Youtube trending', 'I can play guitar', 'I will play guitar today']
#
# When Barcelona dream Team Showed Ronaldo Levels#shorts: https://www.youtube.com/shorts/UicK03NRmM0
# Filtered Hashtags: []
#
# Quando ti regalano qualcosa..ma hai una figlia 😩😓😂 #shorts #short: https://www.youtube.com/shorts/9IV4s2F7Qqw
# Filtered Hashtags: []
#
# Sangat ka asar🥲😂 #chetanmonga #comedy #shorts: https://www.youtube.com/shorts/tMeNn4D6txk
# Filtered Hashtags: []
#
# GƠN BÁO ĐỐI ĐẦU GƠN PHỐ PHẦN 8 | KIỆT HÀ TỊNH #shorts: https://www.youtube.com/shorts/tkQ-WHC4K2M
# Filtered Hashtags: []
#
# Uth puttar uth😂🤦‍♂️🤣#babache #viral #funny #comedy #youtubeshorts #shorts: https://www.youtube.com/shorts/EmwcLIbuiLo
# Filtered Hashtags: ['babache fany', 'Pakistani tiktok funny videos', 'top 10 funny shorts', 'Indian funny videos']
#
# P2: LA ACADEMIA DE SÚPER HÉROES 🦸‍♂️😱💥 #historias #poderes #pov #shorts #tiktok: https://www.youtube.com/shorts/RQKMQP-eY_g
# Filtered Hashtags: []
#
# Sisters dance challenge 😅 #shorts #jonathanjoly #sacconejolys  #justdance2024: https://www.youtube.com/shorts/IP1e6DGyWF8
# Filtered Hashtags: []
#
# ULANG TAHUN - PODTIFFA HORROR #POV #shorts #horrorstories: https://www.youtube.com/shorts/wpquFC5vsPI
# Filtered Hashtags: ['ulng', 'thn', 'thun', 'tahn']
#
# Cậu Bé Người Rừng P207 | Lùn Tippi &amp; Anh tippi Đã Bình Phục - Tippi TV #shorts: https://www.youtube.com/shorts/Gjq2Q_0EHdk
# Filtered Hashtags: ['Tippi TV', 'Lùn Tippi', 'luntippi4.0', 'chân gà', 'xúc xích', 'đại ca', 'cậu bé tốt bụng', 'cậu bé nhà ngèo', 'người anh tham lam', 'cậu bé người rừng', 'người rừng', 'anh tippi', 'cậu bé mũ vàng', 'mũ vàng', 'cậu bé nhà nghèo tốt bụng', 'cô bé nhà ngèo tốt bụng', 'cậu bé áo hồng']
#
# Sagawa1gou funny video 😂😂😂 | SAGAWA Best Shorts 2023 #shorts: https://www.youtube.com/shorts/bFOuSL3LYxY
# Filtered Hashtags: []
#
# I CAN&#39;T BELIEVE I GOT THESE 🥰💖 #shorts: https://www.youtube.com/shorts/F0udWfscTDI
# Filtered Hashtags: ['shoes', 'shoe haul', 'unboxing', 'adidas haul', 'shoe unboxing', 'sambas', 'gazelles', 'adidas', 'adidas shoes', 'kass', 'kass parker', 'just kass', 'new shoes', 'unbox my shoes with me', 'pink adidas', 'adidas gazelle', 'adidas sambas', 'newest adidas', 'newest shoes', 'shoe tour', 'shoe update', 'kassadee', 'kass nelson', 'pink hoodie', 'unbox with me', 'big unboxing', 'adidas unboxing', 'not ready', "I can't believe it", 'packages', 'favorite color']
#
# How Is She So Strong? #shorts: https://www.youtube.com/shorts/nVN53KrNCqA
# Filtered Hashtags: []
#
# The GOAT destroyed ARAUJO#shorts: https://www.youtube.com/shorts/xlltvDdZMJg
# Filtered Hashtags: []
#
# Bhooto ka school 😂😬||zoya sheikh #viral #trending #shorts #zoyasheikh: https://www.youtube.com/shorts/y-Zatc99sG0
# Filtered Hashtags: []
#
# [AMSR] Mystery CRACKERS Advent Calendar - DAY 9!!🎅💅🏻✨ #Shorts: https://www.youtube.com/shorts/AgeuUtXINtE
# Filtered Hashtags: []
# Data saved to youtube_shorts_data.xlsx

# %%
def search_by_hashtag_function(api_key, hashtag):
    # 創建 YouTube API 客戶端
    youtube = build('youtube', 'v3', developerKey=api_key)

    # 設定搜索請求
    request = youtube.search().list(
        part='id,snippet',
        q=f'#{hashtag}',
        type='video',
        order='viewCount',
        maxResults=50  # 根據需求調整
    )

    # 初始化搜尋結果
    search_results = []

    try:
        # 發送 API 請求
        response = request.execute()

        # 處理搜索結果
        for item in response['items']:
            video_id = item['id']['videoId']
            video_title = item['snippet']['title']
            video_url = f'https://www.youtube.com/watch?v={video_id}'

            search_results.append({'Title': video_title, 'URL': video_url})

    except HttpError as e:
        print(f'An error occurred: {e}')

    return search_results

# 獲取用戶輸入
search_hashtag = input("請輸入想查找的 hashtag：")

# 調用搜尋函數，並取得搜尋結果
search_results = search_by_hashtag_function(api_key, search_hashtag)

# 處理搜尋結果
for item in search_results:
    print(f"{item['Title']}: {item['URL']}")
# Out:
# 請輸入想查找的 hashtag：tiktok
# Ke$ha - TiK ToK (Official HD Video): https://www.youtube.com/watch?v=iP6XpLQM2Cs
# She can stand for herself 😒 / XO TEAM TikTok #marysenn #xoteam #tiktok: https://www.youtube.com/watch?v=WACd_J4lh4U
# Bear brown funny moments | Tik Tok funny video: https://www.youtube.com/watch?v=06sqIpTr8mo
# 0 đồng ăn gì? p61 #shorts #tiktok #foryou #xuhuong #fyp #langlieu: https://www.youtube.com/watch?v=2_pMBCeNV6g
# Pick Your Best? 😍 Tiktok Compilation 💘 Pinned your comment 📌#226 #shorts #dance #ytviral #ytshorts: https://www.youtube.com/watch?v=PUIAzZf8xPw
# Phao - 2 Phut Hon (KAIZ Remix) | TikTok Vietnamese Music 2020: https://www.youtube.com/watch?v=yoZy2E17-50
# Deadpool saved mini boy😅 #tiktok: https://www.youtube.com/watch?v=HcIyVzsQqIk
# Sigma Girl Power #tiktok #sigmameme #funny: https://www.youtube.com/watch?v=gMfjP5eYV_I
# Awezdarbar New tik tok video: https://www.youtube.com/watch?v=6Kbkgf0RWmM
# TIK TOK DE CARLOS FERIA #shorts: https://www.youtube.com/watch?v=5hf0qXahu_E
# Best Tik Tok Challenge with Christmas Door 003 #shorts by Super Max: https://www.youtube.com/watch?v=-sZNYNksQH0
# Perfect #beatbox #tiktok: https://www.youtube.com/watch?v=5T1sBKbtOyg
# Spider-Man funny video 😂😂😂 | SPIDER-MAN Best TikTok May 2023 Part35 #shorts #sigma: https://www.youtube.com/watch?v=7dUY12c4Xwo
# It works? #beatbox #tiktok: https://www.youtube.com/watch?v=kszVmSqPYMs
# TikTok makeup: https://www.youtube.com/watch?v=hUfJBg5Fzyo
# Spider-Man funny video 😂😂😂 | SPIDER-MAN Best TikTok December 2022 Part236 #shorts: https://www.youtube.com/watch?v=V3TGUPhEJJU
# FINAL EPICO! 😜 Videos de risas! Si te ries pierdes!🤣 #shorts #tiktok: https://www.youtube.com/watch?v=ex29DBmxSNM
# ЭРА ВЫЛОЖИЛА НОВЫЙ ТИК ТОК | TIKTOK | era_ays 94103: https://www.youtube.com/watch?v=QNK_WuEqIPc
# Perfect #beatbox #tiktok: https://www.youtube.com/watch?v=LT6U6uw0yaE
# 😲REAL Fruit Cake + Mango Latte, So Perfect!😻 | Chef Cat Cooking  #tiktok #Shorts: https://www.youtube.com/watch?v=FTnMyF-Vfpg
# Spider-Man funny video 😂😂😂 | SPIDER-MAN Best TikTok March 2023 Part101 #shorts #sigma: https://www.youtube.com/watch?v=TVdl0Tbj6bQ
# (BLA DANCE)Who&#39;stheBestDancer?DRACULA VS LA TIKTOK VS MEIKA VS BABY#shorts #tiktok #viral: https://www.youtube.com/watch?v=eGVSGWiLVoo
# Mink Mink Mink #beatbox #tiktok: https://www.youtube.com/watch?v=Ek-8AYu0oSU
# Stole a Stoller!😂🤪😱😂 #damus #tiktok #comedy #funny #family #cute: https://www.youtube.com/watch?v=uG7ekOtCs4k
# Ellakasumovic en tiktok 🥰🤩: https://www.youtube.com/watch?v=0JeDAhpGajk
# Chicken Wings Crazy Dance 😂😂😂 #damus #tiktok #comedy #family: https://www.youtube.com/watch?v=l3_EymR4Otc
# Trào lưu tiktok nhiều người thích xem nhất ✅ #2179: https://www.youtube.com/watch?v=gsxiPDz8VCg
# Poor Mom 😭 Wednesday always will protect you 😭😭 #shorts TikTok by Anna Kova: https://www.youtube.com/watch?v=PYAKd2D4k3o
# Sigma Girl Power #tiktok #sigmameme #funny: https://www.youtube.com/watch?v=_ZRfP_pKo7U
# Lost Girl and Unlucky Duo At The Beach😂‼️ | JJaiPan #Shorts #tiktok: https://www.youtube.com/watch?v=ZAIXtq3beEI
# Trending Gadgets!😍, Smart Appliances, Kitchen Tools Utensils, Home Cleaning/Beauty, tiktok #shorts: https://www.youtube.com/watch?v=wREL_YSOWgQ
# POV: You dream of getting a job at the most fashionable magazine #tiktok #xoteam #shorts: https://www.youtube.com/watch?v=vTUxNKwT--g
# 🦑 #elsarca #tiktok #xoteam #dance: https://www.youtube.com/watch?v=lCDZxdXARKg
# G.E.M.【倒數 TIK TOK】Official MV [HD] 鄧紫棋: https://www.youtube.com/watch?v=ma7r2HGqwXs
# Hero Girl and Mean Duo At The Beach😂‼️ | JJaiPan #Shorts #tiktok: https://www.youtube.com/watch?v=dIiTHWHx0kI
# 닭은 춤출 수 있어❗️🐔A chicken can dance #tiktok #shorts: https://www.youtube.com/watch?v=s3sVL0U2iAU
# BANANA CAT 😭 - tiktok trend: https://www.youtube.com/watch?v=Vn4u_SBLfb4
# TikTok hay - c122  #shorts #tiktok #xuhuong: https://www.youtube.com/watch?v=7TmWhy3aj30
# Who is your love on tik tok 2022 1232: https://www.youtube.com/watch?v=IU5-zP-3Rjo
# (kiss💋) Xoteam VS Kikakiim#tiktok: https://www.youtube.com/watch?v=UyvNLyM5U2I
# Funny Kid and Angry Dad😂😂😂 #damus #tiktok #comedy #family: https://www.youtube.com/watch?v=5q72T7PUwng
# HungryBoys funny video😂😂😂|M2DK Best TikTok June 2023 #shorts #TikTok #m2dk: https://www.youtube.com/watch?v=GihPkaU5V9k
# He doesn&#39;t want mom to be sad 🥺🥰LeoNata family #shorts TikTok: https://www.youtube.com/watch?v=-5XERcoF6NY
# TiK ToK: https://www.youtube.com/watch?v=u5uSlUKBEDc
# TikTok - Fico para Dentro ou Corro para Fora? Simpsons o Filme: https://www.youtube.com/watch?v=F1NP6cgnGxo
# Perfect #beatbox #tiktok: https://www.youtube.com/watch?v=YdgRcnxNhmc
# Spider-Man funny video 😂😂😂 | SPIDER-MAN Best TikTok May 2023 Part10 #shorts #sigma: https://www.youtube.com/watch?v=vzafwSN_l7I
# Brothers together💪🏻 #tiktok: https://www.youtube.com/watch?v=fd-7f1AULEg
# Yummy 😋 / XO TEAM TikTok #xoteam #tiktok #tiktoktrend #shorts: https://www.youtube.com/watch?v=F_6lDaq6ZkU
# I love.. #Beatbox #tiktok: https://www.youtube.com/watch?v=fVMSufJ5M_Y
