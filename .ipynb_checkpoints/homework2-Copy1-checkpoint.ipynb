# %%
#將資料化為易讀形式並按照學測報名序號印出
import json
import pprint as pp

with open('111學年度總榜單.json', encoding='utf-8') as file:
    data = json.load(file)
    
sorted_data = sorted(data, key=lambda x: x['學測報名序號'])
print("按照學測報名序號排列：")
pp.pprint(sorted_data, sort_dicts=False)
# Out:
# 按照學測報名序號排列：
# [{'學測報名序號': 26830101,
#   '班級': '301',
#   '座號': '01',
#   '錄取學校': '真理大學',
#   '錄取系所': '企業管理學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830102,
#   '班級': '301',
#   '座號': '02',
#   '錄取學校': '臺北市立大學',
#   '錄取系所': '教育學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830103,
#   '班級': '301',
#   '座號': '03',
#   '錄取學校': '世新大學',
#   '錄取系所': '觀光學系觀光規劃暨資源管理組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830104,
#   '班級': '301',
#   '座號': '04',
#   '錄取學校': '世新大學',
#   '錄取系所': '日本語文學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830105,
#   '班級': '301',
#   '座號': '05',
#   '錄取學校': '朝陽科技大學',
#   '錄取系所': '建築系室內設計組',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26830106,
#   '班級': '301',
#   '座號': '06',
#   '錄取學校': '高雄醫學大學',
#   '錄取系所': '醫學社會學與社會工作學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830107,
#   '班級': '301',
#   '座號': '07',
#   '錄取學校': '實踐大學',
#   '錄取系所': '服飾設計與經營學系藝術創作設計組(高雄校區)',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830108,
#   '班級': '301',
#   '座號': '08',
#   '錄取學校': '致理科技大學',
#   '錄取系所': '資訊管理系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26830109,
#   '班級': '301',
#   '座號': '09',
#   '錄取學校': '萬能科技大學',
#   '錄取系所': '時尚造型設計系時尚造型設計組',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26830110,
#   '班級': '301',
#   '座號': '10',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '商業管理系（進修部）',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26830111,
#   '班級': '301',
#   '座號': '11',
#   '錄取學校': '大阪國際大學',
#   '錄取系所': '國際觀光系',
#   '入學管道': '出國'},
#  {'學測報名序號': 26830112,
#   '班級': '301',
#   '座號': '12',
#   '錄取學校': '淡江大學',
#   '錄取系所': '管理科學學系(大數據資料分析應用組)',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830113,
#   '班級': '301',
#   '座號': '13',
#   '錄取學校': '真理大學',
#   '錄取系所': '財務金融學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830114,
#   '班級': '301',
#   '座號': '14',
#   '錄取學校': '世新大學',
#   '錄取系所': '日本語文學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830115,
#   '班級': '301',
#   '座號': '15',
#   '錄取學校': '致理科技大學',
#   '錄取系所': '資訊管理系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26830116,
#   '班級': '301',
#   '座號': '16',
#   '錄取學校': '佛光大學',
#   '錄取系所': '外國語文學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830118,
#   '班級': '301',
#   '座號': '18',
#   '錄取學校': '真理大學',
#   '錄取系所': '觀光事業學系餐旅管理組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830119,
#   '班級': '301',
#   '座號': '19',
#   '錄取學校': '實踐大學',
#   '錄取系所': '服裝設計學系(臺北校區)',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830120,
#   '班級': '301',
#   '座號': '20',
#   '錄取學校': '德明財經科技大學',
#   '錄取系所': '國際貿易系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26830121,
#   '班級': '301',
#   '座號': '21',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '醫療資訊與管理學系健康產業管理組（桃園校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830122,
#   '班級': '301',
#   '座號': '22',
#   '錄取學校': '元智大學',
#   '錄取系所': '中國語文學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830123,
#   '班級': '301',
#   '座號': '23',
#   '錄取學校': '世新大學',
#   '錄取系所': '行政管理學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830124,
#   '班級': '301',
#   '座號': '24',
#   '錄取學校': '佛光大學',
#   '錄取系所': '傳播系廣告公關組',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26830125,
#   '班級': '301',
#   '座號': '25',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '餐旅系（進修部）',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26830126,
#   '班級': '301',
#   '座號': '26',
#   '錄取學校': '東海大學',
#   '錄取系所': '法律學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830127,
#   '班級': '301',
#   '座號': '27',
#   '錄取學校': '國立體育大學',
#   '錄取系所': '陸上運動技術學系（游泳）',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26830128,
#   '班級': '301',
#   '座號': '28',
#   '錄取學校': '東吳大學',
#   '錄取系所': '英文學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830130,
#   '班級': '301',
#   '座號': '30',
#   '錄取學校': '東吳大學',
#   '錄取系所': '社會學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830131,
#   '班級': '301',
#   '座號': '31',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '日文系（進修部）',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26830132,
#   '班級': '301',
#   '座號': '32',
#   '錄取學校': '義守大學',
#   '錄取系所': '應用英語學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830133,
#   '班級': '301',
#   '座號': '33',
#   '錄取學校': '臺北城市科技大學',
#   '錄取系所': '流行音樂系',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26830134,
#   '班級': '301',
#   '座號': '34',
#   '錄取學校': '國立臺南大學',
#   '錄取系所': '文化與自然資源學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830201,
#   '班級': '302',
#   '座號': '01',
#   '錄取學校': '東吳大學',
#   '錄取系所': '國際經營與貿易學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830202,
#   '班級': '302',
#   '座號': '02',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '西班牙語文學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830203,
#   '班級': '302',
#   '座號': '03',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '企業管理學系品牌行銷組（臺北校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830204,
#   '班級': '302',
#   '座號': '04',
#   '錄取學校': '中原大學',
#   '錄取系所': '企業管理學系工商管理組',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830205,
#   '班級': '302',
#   '座號': '05',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '大眾傳播學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830206,
#   '班級': '302',
#   '座號': '06',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '韓國語文學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830207,
#   '班級': '302',
#   '座號': '07',
#   '錄取學校': '亞洲大學',
#   '錄取系所': '財經法律學系科技法律組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830208,
#   '班級': '302',
#   '座號': '08',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '動漫文創設計學士學位學程（桃園校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830209,
#   '班級': '302',
#   '座號': '09',
#   '錄取學校': '國立聯合大學',
#   '錄取系所': '文化觀光產業學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830210,
#   '班級': '302',
#   '座號': '10',
#   '錄取學校': '世新大學',
#   '錄取系所': '廣播電視電影學系電視組',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830211,
#   '班級': '302',
#   '座號': '11',
#   '錄取學校': '國立體育大學',
#   '錄取系所': '適應體育學系(一般組)',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830212,
#   '班級': '302',
#   '座號': '12',
#   '錄取學校': '實踐大學',
#   '錄取系所': '企業管理學系(臺北校區)',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830213,
#   '班級': '302',
#   '座號': '13',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '勞動暨人力資源學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830214,
#   '班級': '302',
#   '座號': '14',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '中國文學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830215,
#   '班級': '302',
#   '座號': '15',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '公共事務與行政管理學系（桃園校區）',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830216,
#   '班級': '302',
#   '座號': '16',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '觀光事業學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830217,
#   '班級': '302',
#   '座號': '17',
#   '錄取學校': '義守大學',
#   '錄取系所': '應用日語學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830218,
#   '班級': '302',
#   '座號': '18',
#   '錄取學校': '實踐大學',
#   '錄取系所': '資訊模擬與設計學系互動遊戲設計組(高雄校區)',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830219,
#   '班級': '302',
#   '座號': '19',
#   '錄取學校': '康寧大學',
#   '錄取系所': '嬰幼兒保育學系(台北校區)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830220,
#   '班級': '302',
#   '座號': '20',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '資訊傳播學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830221,
#   '班級': '302',
#   '座號': '21',
#   '錄取學校': '中華大學',
#   '錄取系所': '景觀建築學系產品設計組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830222,
#   '班級': '302',
#   '座號': '22',
#   '錄取學校': '東海大學',
#   '錄取系所': '社會工作學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830223,
#   '班級': '302',
#   '座號': '23',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '義大利語文學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830224,
#   '班級': '302',
#   '座號': '24',
#   '錄取學校': '大同大學',
#   '錄取系所': '應用外語學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830225,
#   '班級': '302',
#   '座號': '25',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '歷史系',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26830226,
#   '班級': '302',
#   '座號': '26',
#   '錄取學校': '國立臺南大學',
#   '錄取系所': '戲劇創作與應用學系(男)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830227,
#   '班級': '302',
#   '座號': '27',
#   '錄取學校': '亞洲大學',
#   '錄取系所': '休閒與遊憩管理學系餐旅事業管理組',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830229,
#   '班級': '302',
#   '座號': '29',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '商品設計學系（桃園校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830230,
#   '班級': '302',
#   '座號': '30',
#   '錄取學校': '淡江大學',
#   '錄取系所': '全球政治經濟學系全英語學士班',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830231,
#   '班級': '302',
#   '座號': '31',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '中國文學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830232,
#   '班級': '302',
#   '座號': '32',
#   '錄取學校': '長庚大學',
#   '錄取系所': '醫務管理學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830301,
#   '班級': '303',
#   '座號': '01',
#   '錄取學校': '萬能科技大學',
#   '錄取系所': '餐飲管理系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26830302,
#   '班級': '303',
#   '座號': '02',
#   '錄取學校': '臺北醫學大學',
#   '錄取系所': '醫務管理學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830303,
#   '班級': '303',
#   '座號': '03',
#   '錄取學校': '世新大學',
#   '錄取系所': '法律學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830304,
#   '班級': '303',
#   '座號': '04',
#   '錄取學校': '龍華科技大學',
#   '錄取系所': '文化創意與數位媒體設計系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26830305,
#   '班級': '303',
#   '座號': '05',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '觀光事業學系（桃園校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830306,
#   '班級': '303',
#   '座號': '06',
#   '錄取學校': '龍華科技大學',
#   '錄取系所': '文化創意與數位媒體設計系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26830307,
#   '班級': '303',
#   '座號': '07',
#   '錄取學校': '玄奘大學',
#   '錄取系所': '時尚設計學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830309,
#   '班級': '303',
#   '座號': '09',
#   '錄取學校': '淡江大學',
#   '錄取系所': '教育科技學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830310,
#   '班級': '303',
#   '座號': '10',
#   '錄取學校': '世新大學',
#   '錄取系所': '法律學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830311,
#   '班級': '303',
#   '座號': '11',
#   '錄取學校': '亞洲大學',
#   '錄取系所': '休閒與遊憩管理學系餐旅事業管理組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830312,
#   '班級': '303',
#   '座號': '12',
#   '錄取學校': '國立臺中教育大學',
#   '錄取系所': '諮商與應用心理學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830313,
#   '班級': '303',
#   '座號': '13',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '商業設計學系（桃園校區）',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830314,
#   '班級': '303',
#   '座號': '14',
#   '錄取學校': '國立東華大學',
#   '錄取系所': '中國語文學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830315,
#   '班級': '303',
#   '座號': '15',
#   '錄取學校': '國立臺東大學',
#   '錄取系所': '數位媒體與文教產業學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830316,
#   '班級': '303',
#   '座號': '16',
#   '錄取學校': '國立中正大學',
#   '錄取系所': '勞工關係學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830317,
#   '班級': '303',
#   '座號': '17',
#   '錄取學校': '玄奘大學',
#   '錄取系所': '應用心理學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830318,
#   '班級': '303',
#   '座號': '18',
#   '錄取學校': '開南大學',
#   '錄取系所': '國際物流與運輸管理學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830319,
#   '班級': '303',
#   '座號': '19',
#   '錄取學校': '萬能科技大學',
#   '錄取系所': '化妝品應用與管理系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26830320,
#   '班級': '303',
#   '座號': '20',
#   '錄取學校': '世新大學',
#   '錄取系所': '圖文傳播暨數位出版學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830321,
#   '班級': '303',
#   '座號': '21',
#   '錄取學校': '崇右影藝科技大學',
#   '錄取系所': '表演藝術系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26830322,
#   '班級': '303',
#   '座號': '22',
#   '錄取學校': '真理大學',
#   '錄取系所': '應用日語學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830323,
#   '班級': '303',
#   '座號': '23',
#   '錄取學校': '世新大學',
#   '錄取系所': '新聞學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830324,
#   '班級': '303',
#   '座號': '24',
#   '錄取學校': '世新大學',
#   '錄取系所': '圖文傳播暨數位出版學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830326,
#   '班級': '303',
#   '座號': '26',
#   '錄取學校': '開南大學',
#   '錄取系所': '電影與創意媒體學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830327,
#   '班級': '303',
#   '座號': '27',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '都市計劃與開發管理學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830328,
#   '班級': '303',
#   '座號': '28',
#   '錄取學校': '大同大學',
#   '錄取系所': '事業經營學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830329,
#   '班級': '303',
#   '座號': '29',
#   '錄取學校': '實踐大學',
#   '錄取系所': '休閒產業管理學系休閒文創規劃組(高雄校區)',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830330,
#   '班級': '303',
#   '座號': '30',
#   '錄取學校': '佛光大學',
#   '錄取系所': '歷史學系(A組)',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830331,
#   '班級': '303',
#   '座號': '31',
#   '錄取學校': '佛光大學',
#   '錄取系所': '企業管理學系',
#   '入學管道': '身障'},
#  {'學測報名序號': 26830332,
#   '班級': '303',
#   '座號': '32',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '日本語文學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830334,
#   '班級': '303',
#   '座號': '34',
#   '錄取學校': '龍華科技大學',
#   '錄取系所': '文化創意與數位媒體設計系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26830401,
#   '班級': '304',
#   '座號': '01',
#   '錄取學校': '世新大學',
#   '錄取系所': '公共關係暨廣告學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830402,
#   '班級': '304',
#   '座號': '02',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '觀光事業學系（桃園校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830403,
#   '班級': '304',
#   '座號': '03',
#   '錄取學校': '義守大學',
#   '錄取系所': '創意商品設計學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830404,
#   '班級': '304',
#   '座號': '04',
#   '錄取學校': '國立宜蘭大學',
#   '錄取系所': '休閒產業與健康促進學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830405,
#   '班級': '304',
#   '座號': '05',
#   '錄取學校': '真理大學',
#   '錄取系所': '人文與資訊學系一般組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830406,
#   '班級': '304',
#   '座號': '06',
#   '錄取學校': '佛光大學',
#   '錄取系所': '中國文學與應用學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830407,
#   '班級': '304',
#   '座號': '07',
#   '錄取學校': '國立臺南大學',
#   '錄取系所': '幼兒教育學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830408,
#   '班級': '304',
#   '座號': '08',
#   '錄取學校': '臺北市立大學',
#   '錄取系所': '幼兒教育學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830409,
#   '班級': '304',
#   '座號': '09',
#   '錄取學校': '元智大學',
#   '錄取系所': '社會暨政策科學學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830410,
#   '班級': '304',
#   '座號': '10',
#   '錄取學校': '佛光大學',
#   '錄取系所': '心理學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830411,
#   '班級': '304',
#   '座號': '11',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '企業管理學系品牌行銷組（臺北校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830412,
#   '班級': '304',
#   '座號': '12',
#   '錄取學校': '世新大學',
#   '錄取系所': '資訊傳播學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830413,
#   '班級': '304',
#   '座號': '13',
#   '錄取學校': '國立政治大學',
#   '錄取系所': '傳播學院大一大二不分系(社會組)',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830414,
#   '班級': '304',
#   '座號': '14',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '法國語文學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830415,
#   '班級': '304',
#   '座號': '15',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '圖書資訊學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830416,
#   '班級': '304',
#   '座號': '16',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '社會工作學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830417,
#   '班級': '304',
#   '座號': '17',
#   '錄取學校': '國立金門大學',
#   '錄取系所': '觀光管理學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830418,
#   '班級': '304',
#   '座號': '18',
#   '錄取學校': '國立成功大學',
#   '錄取系所': '台灣文學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830419,
#   '班級': '304',
#   '座號': '19',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '企業管理學系企業管理組(台北校區)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830420,
#   '班級': '304',
#   '座號': '20',
#   '錄取學校': '世新大學',
#   '錄取系所': '日本語文學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830421,
#   '班級': '304',
#   '座號': '21',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '應用日語學系（桃園校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830423,
#   '班級': '304',
#   '座號': '23',
#   '錄取學校': '實踐大學',
#   '錄取系所': '會計學系(臺北校區)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830424,
#   '班級': '304',
#   '座號': '24',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '華語文教學學系應用語言組（桃園校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830426,
#   '班級': '304',
#   '座號': '26',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '應用中國文學系文教組（桃園校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830427,
#   '班級': '304',
#   '座號': '27',
#   '錄取學校': '國立金門大學',
#   '錄取系所': '觀光管理學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830428,
#   '班級': '304',
#   '座號': '28',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '新聞學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830429,
#   '班級': '304',
#   '座號': '29',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '英國語文學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830431,
#   '班級': '304',
#   '座號': '31',
#   '錄取學校': '真理大學',
#   '錄取系所': '應用日語學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830432,
#   '班級': '304',
#   '座號': '32',
#   '錄取學校': '淡江大學',
#   '錄取系所': '中國文學學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830433,
#   '班級': '304',
#   '座號': '33',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '臨床心理學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830434,
#   '班級': '304',
#   '座號': '34',
#   '錄取學校': '國立陽明交通大學',
#   '錄取系所': '人文社會學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830501,
#   '班級': '305',
#   '座號': '01',
#   '錄取學校': '東吳大學',
#   '錄取系所': '哲學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830502,
#   '班級': '305',
#   '座號': '02',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '觀光事業學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830503,
#   '班級': '305',
#   '座號': '03',
#   '錄取學校': '德明財經科技大學',
#   '錄取系所': '財務金融系不動產金融與投資管理組',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26830504,
#   '班級': '305',
#   '座號': '04',
#   '錄取學校': '致理科技大學',
#   '錄取系所': '商務科技管理系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26830506,
#   '班級': '305',
#   '座號': '06',
#   '錄取學校': '義守大學',
#   '錄取系所': '資訊工程學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830507,
#   '班級': '305',
#   '座號': '07',
#   '錄取學校': '國立金門大學',
#   '錄取系所': '國際暨大陸事務學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830508,
#   '班級': '305',
#   '座號': '08',
#   '錄取學校': '國立東華大學',
#   '錄取系所': '法律學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830509,
#   '班級': '305',
#   '座號': '09',
#   '錄取學校': '開南大學',
#   '錄取系所': '國際物流與運輸管理學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830510,
#   '班級': '305',
#   '座號': '10',
#   '錄取學校': '東吳大學',
#   '錄取系所': '英文學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830512,
#   '班級': '305',
#   '座號': '12',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '會計學系會計審計組(台北校區)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830513,
#   '班級': '305',
#   '座號': '13',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '企業管理學系企業管理組（臺北校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830514,
#   '班級': '305',
#   '座號': '14',
#   '錄取學校': '靜宜大學',
#   '錄取系所': '會計學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830515,
#   '班級': '305',
#   '座號': '15',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '經濟學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830516,
#   '班級': '305',
#   '座號': '16',
#   '錄取學校': '東吳大學',
#   '錄取系所': '國際經營與貿易學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830518,
#   '班級': '305',
#   '座號': '18',
#   '錄取學校': '靜宜大學',
#   '錄取系所': '會計學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830519,
#   '班級': '305',
#   '座號': '19',
#   '錄取學校': '靜宜大學',
#   '錄取系所': '會計學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830520,
#   '班級': '305',
#   '座號': '20',
#   '錄取學校': '真理大學',
#   '錄取系所': '運動管理學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830521,
#   '班級': '305',
#   '座號': '21',
#   '錄取學校': '淡江大學',
#   '錄取系所': '國際企業學系國際商學全英語組',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830522,
#   '班級': '305',
#   '座號': '22',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '織品服裝學系服飾設計組',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830523,
#   '班級': '305',
#   '座號': '23',
#   '錄取學校': '玄奘大學',
#   '錄取系所': '社會工作學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830524,
#   '班級': '305',
#   '座號': '24',
#   '錄取學校': '東吳大學',
#   '錄取系所': '資訊管理學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830525,
#   '班級': '305',
#   '座號': '25',
#   '錄取學校': '實踐大學',
#   '錄取系所': '資訊模擬與設計學系互動遊戲設計組(高雄校區)',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830526,
#   '班級': '305',
#   '座號': '26',
#   '錄取學校': '淡江大學',
#   '錄取系所': '經濟學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830527,
#   '班級': '305',
#   '座號': '27',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '資訊傳播學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830528,
#   '班級': '305',
#   '座號': '28',
#   '錄取學校': '靜宜大學',
#   '錄取系所': '會計學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830529,
#   '班級': '305',
#   '座號': '29',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '國際企業管理學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830530,
#   '班級': '305',
#   '座號': '30',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '都市計劃與開發管理學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830531,
#   '班級': '305',
#   '座號': '31',
#   '錄取學校': '國立東華大學',
#   '錄取系所': '管理學院管理科學與財金國際學士學位學程',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830532,
#   '班級': '305',
#   '座號': '32',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '國際企業管理學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830533,
#   '班級': '305',
#   '座號': '33',
#   '錄取學校': '長庚大學',
#   '錄取系所': '工商管理學系工業管理組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830534,
#   '班級': '305',
#   '座號': '34',
#   '錄取學校': '淡江大學',
#   '錄取系所': '國際企業學系經貿管理組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830535,
#   '班級': '305',
#   '座號': '35',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '國際企業管理學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830536,
#   '班級': '305',
#   '座號': '36',
#   '錄取學校': '義守大學',
#   '錄取系所': '數位多媒體設計學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830601,
#   '班級': '306',
#   '座號': '01',
#   '錄取學校': '東吳大學',
#   '錄取系所': '英文學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830602,
#   '班級': '306',
#   '座號': '02',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '休閒遊憩管理學系（桃園校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830604,
#   '班級': '306',
#   '座號': '04',
#   '錄取學校': '靜宜大學',
#   '錄取系所': '財務金融學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830605,
#   '班級': '306',
#   '座號': '05',
#   '錄取學校': '大同大學',
#   '錄取系所': '應用外語學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830606,
#   '班級': '306',
#   '座號': '06',
#   '錄取學校': '東海大學',
#   '錄取系所': '高齡健康與運動科學學士學位學程',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830607,
#   '班級': '306',
#   '座號': '07',
#   '錄取學校': '東吳大學',
#   '錄取系所': '財務工程與精算數學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830608,
#   '班級': '306',
#   '座號': '08',
#   '錄取學校': '元智大學',
#   '錄取系所': '管理學院學士班(主修：企業管理)',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830609,
#   '班級': '306',
#   '座號': '09',
#   '錄取學校': '陸軍軍官學校',
#   '錄取系所': '應用外文',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26830610,
#   '班級': '306',
#   '座號': '10',
#   '錄取學校': '中原大學',
#   '錄取系所': '特殊教育學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830611,
#   '班級': '306',
#   '座號': '11',
#   '錄取學校': '東海大學',
#   '錄取系所': '社會工作學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830612,
#   '班級': '306',
#   '座號': '12',
#   '錄取學校': '淡江大學',
#   '錄取系所': '運輸管理學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830613,
#   '班級': '306',
#   '座號': '13',
#   '錄取學校': '佛光大學',
#   '錄取系所': '產品與媒體設計學系(商業媒體設計組)(二)',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830614,
#   '班級': '306',
#   '座號': '14',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '國際企業學系外貿行銷管理組（臺北校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830615,
#   '班級': '306',
#   '座號': '15',
#   '錄取學校': '東吳大學',
#   '錄取系所': '經濟學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830616,
#   '班級': '306',
#   '座號': '16',
#   '錄取學校': '佛光大學',
#   '錄取系所': '社會學暨社會工作學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830617,
#   '班級': '306',
#   '座號': '17',
#   '錄取學校': '東吳大學',
#   '錄取系所': '日本語文學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830618,
#   '班級': '306',
#   '座號': '18',
#   '錄取學校': '國立金門大學',
#   '錄取系所': '國際暨大陸事務學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830619,
#   '班級': '306',
#   '座號': '19',
#   '錄取學校': '國立東華大學',
#   '錄取系所': '特殊教育學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830620,
#   '班級': '306',
#   '座號': '20',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '國際企業學系外貿行銷管理組（臺北校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830621,
#   '班級': '306',
#   '座號': '21',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '金融科技應用學士學位學程(桃園校區)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830622,
#   '班級': '306',
#   '座號': '22',
#   '錄取學校': '崑山科技大學',
#   '錄取系所': '機械工程系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26830623,
#   '班級': '306',
#   '座號': '23',
#   '錄取學校': '靜宜大學',
#   '錄取系所': '財務金融學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830624,
#   '班級': '306',
#   '座號': '24',
#   '錄取學校': '元智大學',
#   '錄取系所': '管理學院學士班(主修：企業管理)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830625,
#   '班級': '306',
#   '座號': '25',
#   '錄取學校': '淡江大學',
#   '錄取系所': '國際企業學系經貿管理組',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830626,
#   '班級': '306',
#   '座號': '26',
#   '錄取學校': '萬能科技大學',
#   '錄取系所': '餐飲管理系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26830627,
#   '班級': '306',
#   '座號': '27',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '觀光事業學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830628,
#   '班級': '306',
#   '座號': '28',
#   '錄取學校': '國立嘉義大學',
#   '錄取系所': '資訊管理學系(社會組)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830629,
#   '班級': '306',
#   '座號': '29',
#   '錄取學校': '國立臺中教育大學',
#   '錄取系所': '國際企業學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830630,
#   '班級': '306',
#   '座號': '30',
#   '錄取學校': '東吳大學',
#   '錄取系所': '經濟學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830631,
#   '班級': '306',
#   '座號': '31',
#   '錄取學校': '中原大學',
#   '錄取系所': '工業與系統工程學系管理組',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830632,
#   '班級': '306',
#   '座號': '32',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '資訊傳播學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830633,
#   '班級': '306',
#   '座號': '33',
#   '錄取學校': '靜宜大學',
#   '錄取系所': '財務工程學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830634,
#   '班級': '306',
#   '座號': '34',
#   '錄取學校': '淡江大學',
#   '錄取系所': '運輸管理學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830635,
#   '班級': '306',
#   '座號': '35',
#   '錄取學校': '國立臺北大學',
#   '錄取系所': '金融與合作經營學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830636,
#   '班級': '306',
#   '座號': '36',
#   '錄取學校': '開南大學',
#   '錄取系所': '觀光與餐飲旅館學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830637,
#   '班級': '306',
#   '座號': '37',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '餐旅管理學系(桃園校區)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830701,
#   '班級': '307',
#   '座號': '01',
#   '錄取學校': '逢甲大學',
#   '錄取系所': '國際經營與貿易學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830702,
#   '班級': '307',
#   '座號': '02',
#   '錄取學校': '國立暨南國際大學',
#   '錄取系所': '財務金融學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830703,
#   '班級': '307',
#   '座號': '03',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '中國文學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830704,
#   '班級': '307',
#   '座號': '04',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '會計學系稅務規劃組（臺北校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830705,
#   '班級': '307',
#   '座號': '05',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '進修部經濟系',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26830707,
#   '班級': '307',
#   '座號': '07',
#   '錄取學校': '中原大學',
#   '錄取系所': '資訊管理學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830708,
#   '班級': '307',
#   '座號': '08',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '應用中國文學系文教組（桃園校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830709,
#   '班級': '307',
#   '座號': '09',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '應用統計與資料科學學系大數據管理組（桃園校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830710,
#   '班級': '307',
#   '座號': '10',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '應用英語學系英語商務組（桃園校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830711,
#   '班級': '307',
#   '座號': '11',
#   '錄取學校': '真理大學',
#   '錄取系所': '資訊管理學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830712,
#   '班級': '307',
#   '座號': '12',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '進修部大傳系',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26830713,
#   '班級': '307',
#   '座號': '13',
#   '錄取學校': '國立臺北教育大學',
#   '錄取系所': '教育學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830714,
#   '班級': '307',
#   '座號': '14',
#   '錄取學校': '東吳大學',
#   '錄取系所': '國際經營與貿易學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830715,
#   '班級': '307',
#   '座號': '15',
#   '錄取學校': '長庚大學',
#   '錄取系所': '工商管理學系(數智商務組)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830716,
#   '班級': '307',
#   '座號': '16',
#   '錄取學校': '東海大學',
#   '錄取系所': '財務金融學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830717,
#   '班級': '307',
#   '座號': '17',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '兒童與家庭學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830718,
#   '班級': '307',
#   '座號': '18',
#   '錄取學校': '真理大學',
#   '錄取系所': '統計資訊與精算學系商業應用組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830719,
#   '班級': '307',
#   '座號': '19',
#   '錄取學校': '淡江大學',
#   '錄取系所': '財務金融學系全球財務管理全英語學士班',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830720,
#   '班級': '307',
#   '座號': '20',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '風險管理與保險學系保險金融與行銷組（臺北校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830721,
#   '班級': '307',
#   '座號': '21',
#   '錄取學校': '東海大學',
#   '錄取系所': '企業管理學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830722,
#   '班級': '307',
#   '座號': '22',
#   '錄取學校': '淡江大學',
#   '錄取系所': '資訊傳播學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830723,
#   '班級': '307',
#   '座號': '23',
#   '錄取學校': '實踐大學',
#   '錄取系所': '應用中文學系劇本創作組(高雄校區)',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830724,
#   '班級': '307',
#   '座號': '24',
#   '錄取學校': '中山醫學大學',
#   '錄取系所': '醫療產業科技管理學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830725,
#   '班級': '307',
#   '座號': '25',
#   '錄取學校': '國立暨南國際大學',
#   '錄取系所': '社會政策與社會工作學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830726,
#   '班級': '307',
#   '座號': '26',
#   '錄取學校': '淡江大學',
#   '錄取系所': '統計學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830727,
#   '班級': '307',
#   '座號': '27',
#   '錄取學校': '東吳大學',
#   '錄取系所': '國際經營與貿易學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830728,
#   '班級': '307',
#   '座號': '28',
#   '錄取學校': '亞洲大學',
#   '錄取系所': '財經法律學系財經法律組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830729,
#   '班級': '307',
#   '座號': '29',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '進修部大傳系',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26830730,
#   '班級': '307',
#   '座號': '30',
#   '錄取學校': '國立臺中教育大學',
#   '錄取系所': '資訊工程學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830731,
#   '班級': '307',
#   '座號': '31',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '經濟與金融學系產業經濟組（桃園校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830733,
#   '班級': '307',
#   '座號': '33',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '法律學系(台北校區)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830734,
#   '班級': '307',
#   '座號': '34',
#   '錄取學校': '逢甲大學',
#   '錄取系所': '統計學系大數據分析與市場決策組',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830735,
#   '班級': '307',
#   '座號': '35',
#   '錄取學校': '國立高雄師範大學',
#   '錄取系所': '國文學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830736,
#   '班級': '307',
#   '座號': '36',
#   '錄取學校': '國立體育大學',
#   '錄取系所': '休閒產業經營學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830801,
#   '班級': '308',
#   '座號': '01',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '應用統計與資料科學學系大數據管理組（桃園校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830802,
#   '班級': '308',
#   '座號': '02',
#   '錄取學校': '醒吾科技大學',
#   '錄取系所': '餐館學系',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26830803,
#   '班級': '308',
#   '座號': '03',
#   '錄取學校': '靜宜大學',
#   '錄取系所': '會計學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830804,
#   '班級': '308',
#   '座號': '04',
#   '錄取學校': '國立體育大學',
#   '錄取系所': '休閒產業經營學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830805,
#   '班級': '308',
#   '座號': '05',
#   '錄取學校': '實踐大學',
#   '錄取系所': '國際經營與貿易學系(臺北校區)',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830806,
#   '班級': '308',
#   '座號': '06',
#   '錄取學校': '實踐大學',
#   '錄取系所': '會計學系(臺北校區)',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830807,
#   '班級': '308',
#   '座號': '07',
#   '錄取學校': '醒吾科技大學',
#   '錄取系所': '餐館學系',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26830808,
#   '班級': '308',
#   '座號': '08',
#   '錄取學校': '世新大學',
#   '錄取系所': '行政管理學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830809,
#   '班級': '308',
#   '座號': '09',
#   '錄取學校': '國立臺北大學',
#   '錄取系所': '進修部社工系',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26830810,
#   '班級': '308',
#   '座號': '10',
#   '錄取學校': '國立中興大學',
#   '錄取系所': '台灣人文創新學士學位學程',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830811,
#   '班級': '308',
#   '座號': '11',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '法文系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830812,
#   '班級': '308',
#   '座號': '12',
#   '錄取學校': '淡江大學',
#   '錄取系所': '管理科學學系(企業經營與行銷流通組)',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830813,
#   '班級': '308',
#   '座號': '13',
#   '錄取學校': '淡江大學',
#   '錄取系所': '資訊管理學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830814,
#   '班級': '308',
#   '座號': '14',
#   '錄取學校': '玄奘大學',
#   '錄取系所': '時尚設計學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830815,
#   '班級': '308',
#   '座號': '15',
#   '錄取學校': '萬能科技大學',
#   '錄取系所': '餐飲管理系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26830816,
#   '班級': '308',
#   '座號': '16',
#   '錄取學校': '世新大學',
#   '錄取系所': '企業管理學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830817,
#   '班級': '308',
#   '座號': '17',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '宗教學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830818,
#   '班級': '308',
#   '座號': '18',
#   '錄取學校': '世新大學',
#   '錄取系所': '觀光學系旅遊暨休閒事業管理組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830819,
#   '班級': '308',
#   '座號': '19',
#   '錄取學校': '佛光大學',
#   '錄取系所': '產品與媒體設計學系（創意產品設計組）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830820,
#   '班級': '308',
#   '座號': '20',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '諮商與工商心理學系(桃園校區)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830821,
#   '班級': '308',
#   '座號': '21',
#   '錄取學校': '陸軍專科學校',
#   '錄取系所': '無',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26830822,
#   '班級': '308',
#   '座號': '22',
#   '錄取學校': '東吳大學',
#   '錄取系所': '企業管理學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830823,
#   '班級': '308',
#   '座號': '23',
#   '錄取學校': '國立聯合大學',
#   '錄取系所': '經營管理學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830825,
#   '班級': '308',
#   '座號': '25',
#   '錄取學校': '真理大學',
#   '錄取系所': '運動管理學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830826,
#   '班級': '308',
#   '座號': '26',
#   '錄取學校': '醒吾科技大學',
#   '錄取系所': '旅應系',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26830827,
#   '班級': '308',
#   '座號': '27',
#   '錄取學校': '國立臺灣體育運動大學',
#   '錄取系所': '體育學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830828,
#   '班級': '308',
#   '座號': '28',
#   '錄取學校': '真理大學',
#   '錄取系所': '應用日語學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830829,
#   '班級': '308',
#   '座號': '29',
#   '錄取學校': '陸軍專科學校',
#   '錄取系所': '無',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26830830,
#   '班級': '308',
#   '座號': '30',
#   '錄取學校': '中原大學',
#   '錄取系所': '財務金融學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830831,
#   '班級': '308',
#   '座號': '31',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '餐旅管理學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830832,
#   '班級': '308',
#   '座號': '32',
#   '錄取學校': '國立金門大學',
#   '錄取系所': '觀光管理學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830833,
#   '班級': '308',
#   '座號': '33',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '圖書資訊學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830834,
#   '班級': '308',
#   '座號': '34',
#   '錄取學校': '國立嘉義大學',
#   '錄取系所': '教育學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830836,
#   '班級': '308',
#   '座號': '36',
#   '錄取學校': '真理大學',
#   '錄取系所': '經濟學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830901,
#   '班級': '309',
#   '座號': '01',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '醫療資訊與管理學系健康產業管理組（桃園校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830902,
#   '班級': '309',
#   '座號': '02',
#   '錄取學校': '世新大學',
#   '錄取系所': '資訊管理學系資訊管理組',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830903,
#   '班級': '309',
#   '座號': '03',
#   '錄取學校': '致理科技大學',
#   '錄取系所': '企業管理系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26830904,
#   '班級': '309',
#   '座號': '04',
#   '錄取學校': '淡江大學',
#   '錄取系所': '風險管理與保險學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830905,
#   '班級': '309',
#   '座號': '05',
#   '錄取學校': '國立聯合大學',
#   '錄取系所': '資訊工程學系(B組)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830906,
#   '班級': '309',
#   '座號': '06',
#   '錄取學校': '淡江大學',
#   '錄取系所': '歷史學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830907,
#   '班級': '309',
#   '座號': '07',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '風險管理與保險學系風險管理組（臺北校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830908,
#   '班級': '309',
#   '座號': '08',
#   '錄取學校': '國立嘉義大學',
#   '錄取系所': '幼兒教育學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830909,
#   '班級': '309',
#   '座號': '09',
#   '錄取學校': '淡江大學',
#   '錄取系所': '法國語文學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830910,
#   '班級': '309',
#   '座號': '10',
#   '錄取學校': '龍華科技大學',
#   '錄取系所': '文化創意與數位媒體設計系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26830911,
#   '班級': '309',
#   '座號': '11',
#   '錄取學校': '中山醫學大學',
#   '錄取系所': '應用外國語言學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830912,
#   '班級': '309',
#   '座號': '12',
#   '錄取學校': '東海大學',
#   '錄取系所': '中國文學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830913,
#   '班級': '309',
#   '座號': '13',
#   '錄取學校': '佛光大學',
#   '錄取系所': '應用經濟學系(國際商務組)',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830914,
#   '班級': '309',
#   '座號': '14',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '公共事務與行政管理學系（桃園校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830915,
#   '班級': '309',
#   '座號': '15',
#   '錄取學校': '中華大學',
#   '錄取系所': '財務管理學系財務金融管理組',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830916,
#   '班級': '309',
#   '座號': '16',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '電子工程學系半導體光電組（桃園校區）',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830917,
#   '班級': '309',
#   '座號': '17',
#   '錄取學校': '國立臺灣大學',
#   '錄取系所': '政治學系公共行政組',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830918,
#   '班級': '309',
#   '座號': '18',
#   '錄取學校': '佛光大學',
#   '錄取系所': '社會學暨社會工作學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830919,
#   '班級': '309',
#   '座號': '19',
#   '錄取學校': '淡江大學',
#   '錄取系所': '財務金融學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830920,
#   '班級': '309',
#   '座號': '20',
#   '錄取學校': '康寧大學',
#   '錄取系所': '嬰幼兒保育學系(台北校區)',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830921,
#   '班級': '309',
#   '座號': '21',
#   '錄取學校': '國立臺北大學',
#   '錄取系所': '進修部不動產與城鄉學系',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26830922,
#   '班級': '309',
#   '座號': '22',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '經濟與金融學系產業經濟組(桃園校區)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830923,
#   '班級': '309',
#   '座號': '23',
#   '錄取學校': '大同大學',
#   '錄取系所': '資訊經營學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830924,
#   '班級': '309',
#   '座號': '24',
#   '錄取學校': '淡江大學',
#   '錄取系所': '教育科技學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830925,
#   '班級': '309',
#   '座號': '25',
#   '錄取學校': '國立體育大學',
#   '錄取系所': '休閒產業經營學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830926,
#   '班級': '309',
#   '座號': '26',
#   '錄取學校': '淡江大學',
#   '錄取系所': '管理科學學系(大數據資料分析應用組)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830927,
#   '班級': '309',
#   '座號': '27',
#   '錄取學校': '真理大學',
#   '錄取系所': '企業管理學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830928,
#   '班級': '309',
#   '座號': '28',
#   '錄取學校': '國立臺灣海洋大學',
#   '錄取系所': '海洋法政學士學位學程',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26830930,
#   '班級': '309',
#   '座號': '30',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '會計學系會計審計組(台北校區)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830932,
#   '班級': '309',
#   '座號': '32',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '諮商與工商心理學系(桃園校區)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830933,
#   '班級': '309',
#   '座號': '33',
#   '錄取學校': '實踐大學',
#   '錄取系所': '金融管理學系金融商品組(高雄校區)',
#   '入學管道': '申請'},
#  {'學測報名序號': 26830934,
#   '班級': '309',
#   '座號': '34',
#   '錄取學校': '淡江大學',
#   '錄取系所': '財務金融學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830935,
#   '班級': '309',
#   '座號': '35',
#   '錄取學校': '淡江大學',
#   '錄取系所': '財務金融學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26830936,
#   '班級': '309',
#   '座號': '36',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '犯罪防治學系(桃園校區)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831002,
#   '班級': '310',
#   '座號': '02',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '中國文學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831004,
#   '班級': '310',
#   '座號': '04',
#   '錄取學校': '龍華科技大學',
#   '錄取系所': '化工與材料工程系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831005,
#   '班級': '310',
#   '座號': '05',
#   '錄取學校': '南華大學',
#   '錄取系所': '建築與景觀學系自然組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831007,
#   '班級': '310',
#   '座號': '07',
#   '錄取學校': '大葉大學',
#   '錄取系所': '環境工程學系(環境管理組)',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831008,
#   '班級': '310',
#   '座號': '08',
#   '錄取學校': '國立屏東大學',
#   '錄取系所': '電腦科學與人工智慧學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831009,
#   '班級': '310',
#   '座號': '09',
#   '錄取學校': '國立宜蘭大學',
#   '錄取系所': '生物機電工程學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831011,
#   '班級': '310',
#   '座號': '11',
#   '錄取學校': '佛光大學',
#   '錄取系所': '應用經濟學系(國際商務組)',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831012,
#   '班級': '310',
#   '座號': '12',
#   '錄取學校': '中原大學',
#   '錄取系所': '資訊工程學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831013,
#   '班級': '310',
#   '座號': '13',
#   '錄取學校': '嘉藥學校財團法人嘉南藥理大學',
#   '錄取系所': '環境工程與科學系環境科技組',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831014,
#   '班級': '310',
#   '座號': '14',
#   '錄取學校': '國立高雄科技大學',
#   '錄取系所': '漁業生產與管理系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831015,
#   '班級': '310',
#   '座號': '15',
#   '錄取學校': '淡江大學',
#   '錄取系所': '土木工程學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831016,
#   '班級': '310',
#   '座號': '16',
#   '錄取學校': '國立宜蘭大學',
#   '錄取系所': '土木工程學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831019,
#   '班級': '310',
#   '座號': '19',
#   '錄取學校': '佛光大學',
#   '錄取系所': '產品與媒體設計學系（創意產品設計組）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831020,
#   '班級': '310',
#   '座號': '20',
#   '錄取學校': '中原大學',
#   '錄取系所': '物理學系物理組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831021,
#   '班級': '310',
#   '座號': '21',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '化學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831022,
#   '班級': '310',
#   '座號': '22',
#   '錄取學校': '佛光大學',
#   '錄取系所': '中國文學與應用學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831024,
#   '班級': '310',
#   '座號': '24',
#   '錄取學校': '中原大學',
#   '錄取系所': '環境工程學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831025,
#   '班級': '310',
#   '座號': '25',
#   '錄取學校': '明新科技大學',
#   '錄取系所': '電機工程系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831026,
#   '班級': '310',
#   '座號': '26',
#   '錄取學校': '黎明技術學院',
#   '錄取系所': '戲劇系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831028,
#   '班級': '310',
#   '座號': '28',
#   '錄取學校': '佛光大學',
#   '錄取系所': '資訊應用學系(動畫與數位內容組)(二)',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831029,
#   '班級': '310',
#   '座號': '29',
#   '錄取學校': '樹德科技大學',
#   '錄取系所': '室內設計系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831031,
#   '班級': '310',
#   '座號': '31',
#   '錄取學校': '佛光大學',
#   '錄取系所': '資訊應用學系(數位遊戲開發組)',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831032,
#   '班級': '310',
#   '座號': '32',
#   '錄取學校': '淡江大學',
#   '錄取系所': '機械與機電工程學系精密機械組',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831101,
#   '班級': '311',
#   '座號': '01',
#   '錄取學校': '中原大學',
#   '錄取系所': '土木工程學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831102,
#   '班級': '311',
#   '座號': '02',
#   '錄取學校': '南臺科技大學',
#   '錄取系所': '生物與食品科技系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831103,
#   '班級': '311',
#   '座號': '03',
#   '錄取學校': '長庚學校財團法人長庚科技大學',
#   '錄取系所': '護理系（林口校區）',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831104,
#   '班級': '311',
#   '座號': '04',
#   '錄取學校': '逢甲大學',
#   '錄取系所': '化學工程學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831105,
#   '班級': '311',
#   '座號': '05',
#   '錄取學校': '黎明技術學院',
#   '錄取系所': '化妝品應用系',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26831106,
#   '班級': '311',
#   '座號': '06',
#   '錄取學校': '臺北城市科技大學',
#   '錄取系所': '烘焙創意與經營管理學士學位學程',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831107,
#   '班級': '311',
#   '座號': '07',
#   '錄取學校': '龍華科技大學',
#   '錄取系所': '化工與材料工程系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831108,
#   '班級': '311',
#   '座號': '08',
#   '錄取學校': '逢甲大學',
#   '錄取系所': '運輸與物流學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831109,
#   '班級': '311',
#   '座號': '09',
#   '錄取學校': '明新科技大學',
#   '錄取系所': '電機工程系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831110,
#   '班級': '311',
#   '座號': '10',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '建築學系(桃園校區)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831111,
#   '班級': '311',
#   '座號': '11',
#   '錄取學校': '淡江大學',
#   '錄取系所': '資訊管理學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831112,
#   '班級': '311',
#   '座號': '12',
#   '錄取學校': '國立臺東大學',
#   '錄取系所': '生命科學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831113,
#   '班級': '311',
#   '座號': '13',
#   '錄取學校': '中原大學',
#   '錄取系所': '工業與系統工程學系工程組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831114,
#   '班級': '311',
#   '座號': '14',
#   '錄取學校': '龍華科技大學',
#   '錄取系所': '資訊網路工程系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831115,
#   '班級': '311',
#   '座號': '15',
#   '錄取學校': '佛光大學',
#   '錄取系所': '資訊應用學系(數位遊戲開發組)',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831116,
#   '班級': '311',
#   '座號': '16',
#   '錄取學校': '中華大學',
#   '錄取系所': '工業管理學系（乙組）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831117,
#   '班級': '311',
#   '座號': '17',
#   '錄取學校': '淡江大學',
#   '錄取系所': '土木工程學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831118,
#   '班級': '311',
#   '座號': '18',
#   '錄取學校': '國立臺灣師範大學',
#   '錄取系所': '物理學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831119,
#   '班級': '311',
#   '座號': '19',
#   '錄取學校': '中原大學',
#   '錄取系所': '土木工程學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831120,
#   '班級': '311',
#   '座號': '20',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '電腦與通訊工程學系（桃園校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831121,
#   '班級': '311',
#   '座號': '21',
#   '錄取學校': '中原大學',
#   '錄取系所': '地景建築學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831122,
#   '班級': '311',
#   '座號': '22',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '應用統計與資料科學學系大數據管理組(桃園校區)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831123,
#   '班級': '311',
#   '座號': '23',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '休閒遊憩管理學系(桃園校區)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831124,
#   '班級': '311',
#   '座號': '24',
#   '錄取學校': '中原大學',
#   '錄取系所': '機械工程學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831125,
#   '班級': '311',
#   '座號': '25',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '人工智慧與資訊安全學士學位學程',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831126,
#   '班級': '311',
#   '座號': '26',
#   '錄取學校': '東海大學',
#   '錄取系所': '化學工程與材料工程學系(製程及能源工程組)',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831127,
#   '班級': '311',
#   '座號': '27',
#   '錄取學校': '淡江大學',
#   '錄取系所': '機械與機電工程學系精密機械組',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831128,
#   '班級': '311',
#   '座號': '28',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '物理學系光電物理組',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831129,
#   '班級': '311',
#   '座號': '29',
#   '錄取學校': '國立中央大學',
#   '錄取系所': '土木工程學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831130,
#   '班級': '311',
#   '座號': '30',
#   '錄取學校': '南臺科技大學',
#   '錄取系所': '電機工程系控制與晶片組',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831131,
#   '班級': '311',
#   '座號': '31',
#   '錄取學校': '黎明技術學院',
#   '錄取系所': '機械工程系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831201,
#   '班級': '312',
#   '座號': '01',
#   '錄取學校': '逢甲大學',
#   '錄取系所': '統計學系大數據分析與市場決策組',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831202,
#   '班級': '312',
#   '座號': '02',
#   '錄取學校': '致理科技大學',
#   '錄取系所': '商務科技管理系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831203,
#   '班級': '312',
#   '座號': '03',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '生物科技學系（桃園校區）',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831204,
#   '班級': '312',
#   '座號': '04',
#   '錄取學校': '亞洲大學',
#   '錄取系所': '數位媒體設計學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831205,
#   '班級': '312',
#   '座號': '05',
#   '錄取學校': '元智大學',
#   '錄取系所': '資訊工程學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831206,
#   '班級': '312',
#   '座號': '06',
#   '錄取學校': '佛光大學',
#   '錄取系所': '歷史學系(A組)',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831207,
#   '班級': '312',
#   '座號': '07',
#   '錄取學校': '義守大學',
#   '錄取系所': '土木工程學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831208,
#   '班級': '312',
#   '座號': '08',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '電腦與通訊工程學系(桃園校區)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831209,
#   '班級': '312',
#   '座號': '09',
#   '錄取學校': '玄奘大學',
#   '錄取系所': '大眾傳播學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831211,
#   '班級': '312',
#   '座號': '11',
#   '錄取學校': '淡江大學',
#   '錄取系所': '統計學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831212,
#   '班級': '312',
#   '座號': '12',
#   '錄取學校': '亞東科技大學',
#   '錄取系所': '機械工程系汽車組',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831213,
#   '班級': '312',
#   '座號': '13',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '物理學系物理組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831214,
#   '班級': '312',
#   '座號': '14',
#   '錄取學校': '元智大學',
#   '錄取系所': '工業工程與管理學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831215,
#   '班級': '312',
#   '座號': '15',
#   '錄取學校': '元智大學',
#   '錄取系所': '電機通訊學院英語學士班',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831216,
#   '班級': '312',
#   '座號': '16',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '電腦與通訊工程學系（桃園校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831217,
#   '班級': '312',
#   '座號': '17',
#   '錄取學校': '元智大學',
#   '錄取系所': '電機工程學系(乙組)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831218,
#   '班級': '312',
#   '座號': '18',
#   '錄取學校': '淡江大學',
#   '錄取系所': '化學學系材料化學組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831219,
#   '班級': '312',
#   '座號': '19',
#   '錄取學校': '義守大學',
#   '錄取系所': '材料科學與工程學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831220,
#   '班級': '312',
#   '座號': '20',
#   '錄取學校': '健行科技大學',
#   '錄取系所': '室內設計系',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26831221,
#   '班級': '312',
#   '座號': '21',
#   '錄取學校': '淡江大學',
#   '錄取系所': '數學學系數學組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831222,
#   '班級': '312',
#   '座號': '22',
#   '錄取學校': '淡江大學',
#   '錄取系所': '化學學系化學與生物化學組',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831223,
#   '班級': '312',
#   '座號': '23',
#   '錄取學校': '東海大學',
#   '錄取系所': '統計學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831224,
#   '班級': '312',
#   '座號': '24',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '資訊管理學系雲端技術管理組（桃園校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831225,
#   '班級': '312',
#   '座號': '25',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '電機工程學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831226,
#   '班級': '312',
#   '座號': '26',
#   '錄取學校': '元智大學',
#   '錄取系所': '電機工程學系(甲組)',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831227,
#   '班級': '312',
#   '座號': '27',
#   '錄取學校': '國立臺東大學',
#   '錄取系所': '應用科學系化學及奈米科學組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831301,
#   '班級': '313',
#   '座號': '01',
#   '錄取學校': '國立臺灣師範大學',
#   '錄取系所': '科技應用與人力資源發展學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831302,
#   '班級': '313',
#   '座號': '2',
#   '錄取學校': '臺北醫學大學',
#   '錄取系所': '藥學系藥學組',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831303,
#   '班級': '313',
#   '座號': '03',
#   '錄取學校': '國立臺南大學',
#   '錄取系所': '生物科技學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831304,
#   '班級': '313',
#   '座號': '04',
#   '錄取學校': '逢甲大學',
#   '錄取系所': '光電科學與工程學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831305,
#   '班級': '313',
#   '座號': '05',
#   '錄取學校': '長庚大學',
#   '錄取系所': '物理治療學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831306,
#   '班級': '313',
#   '座號': '06',
#   '錄取學校': '國立成功大學',
#   '錄取系所': '生物科技與產業科學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831307,
#   '班級': '313',
#   '座號': '07',
#   '錄取學校': '國立聯合大學',
#   '錄取系所': '建築學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831308,
#   '班級': '313',
#   '座號': '08',
#   '錄取學校': '高雄醫學大學',
#   '錄取系所': '物理治療學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831309,
#   '班級': '313',
#   '座號': '09',
#   '錄取學校': '逢甲大學',
#   '錄取系所': '經濟學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831310,
#   '班級': '313',
#   '座號': '10',
#   '錄取學校': '中國醫藥大學',
#   '錄取系所': '藥學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831311,
#   '班級': '313',
#   '座號': '11',
#   '錄取學校': '國立成功大學',
#   '錄取系所': '測量及空間資訊學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831312,
#   '班級': '313',
#   '座號': '12',
#   '錄取學校': '國立中山大學',
#   '錄取系所': '物理學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831313,
#   '班級': '313',
#   '座號': '13',
#   '錄取學校': '逢甲大學',
#   '錄取系所': '資訊工程學系甲組',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831314,
#   '班級': '313',
#   '座號': '14',
#   '錄取學校': '東吳大學',
#   '錄取系所': '數學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831315,
#   '班級': '313',
#   '座號': '15',
#   '錄取學校': '東吳大學',
#   '錄取系所': '物理學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831316,
#   '班級': '313',
#   '座號': '16',
#   '錄取學校': '東海大學',
#   '錄取系所': '資訊工程學系(軟體工程組)',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831317,
#   '班級': '313',
#   '座號': '17',
#   '錄取學校': '國立高雄師範大學',
#   '錄取系所': '電子工程學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831318,
#   '班級': '313',
#   '座號': '18',
#   '錄取學校': '長庚大學',
#   '錄取系所': '電機工程學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831319,
#   '班級': '313',
#   '座號': '19',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '電機工程學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831320,
#   '班級': '313',
#   '座號': '20',
#   '錄取學校': '國立中央大學',
#   '錄取系所': '生命科學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831321,
#   '班級': '313',
#   '座號': '21',
#   '錄取學校': '淡江大學',
#   '錄取系所': '人工智慧學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831322,
#   '班級': '313',
#   '座號': '22',
#   '錄取學校': '國立陽明交通大學',
#   '錄取系所': '土木工程學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831323,
#   '班級': '313',
#   '座號': '23',
#   '錄取學校': '國立臺灣海洋大學',
#   '錄取系所': '河海工程學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831324,
#   '班級': '313',
#   '座號': '24',
#   '錄取學校': '東海大學',
#   '錄取系所': '化學工程與材料工程學系(製程及能源工程組)',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831325,
#   '班級': '313',
#   '座號': '25',
#   '錄取學校': '國立聯合大學',
#   '錄取系所': '機械工程學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831326,
#   '班級': '313',
#   '座號': '26',
#   '錄取學校': '義守大學',
#   '錄取系所': '營養學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831327,
#   '班級': '313',
#   '座號': '27',
#   '錄取學校': '國立彰化師範大學',
#   '錄取系所': '物理學系光電組',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831328,
#   '班級': '313',
#   '座號': '28',
#   '錄取學校': '國立宜蘭大學',
#   '錄取系所': '土木工程學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831329,
#   '班級': '313',
#   '座號': '29',
#   '錄取學校': '國立高雄大學',
#   '錄取系所': '資訊工程學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831401,
#   '班級': '314',
#   '座號': '01',
#   '錄取學校': '長庚學校財團法人長庚科技大學',
#   '錄取系所': '護理系（林口校區）',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831402,
#   '班級': '314',
#   '座號': '02',
#   '錄取學校': '大仁科技大學',
#   '錄取系所': '護理系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831403,
#   '班級': '314',
#   '座號': '03',
#   '錄取學校': '長榮大學',
#   '錄取系所': '健康心理學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831404,
#   '班級': '314',
#   '座號': '04',
#   '錄取學校': '中國醫藥大學',
#   '錄取系所': '公共衛生學院大一不分系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831405,
#   '班級': '314',
#   '座號': '05',
#   '錄取學校': '義守大學',
#   '錄取系所': '護理學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831406,
#   '班級': '314',
#   '座號': '06',
#   '錄取學校': '長庚大學',
#   '錄取系所': '工業設計學系(社會組)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831407,
#   '班級': '314',
#   '座號': '07',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '食品科學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831408,
#   '班級': '314',
#   '座號': '08',
#   '錄取學校': '元培醫事科技大學',
#   '錄取系所': '生物科技暨製藥技術系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831409,
#   '班級': '314',
#   '座號': '09',
#   '錄取學校': '淡江大學',
#   '錄取系所': '化學學系化學與生物化學組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831410,
#   '班級': '314',
#   '座號': '10',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '體育學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831411,
#   '班級': '314',
#   '座號': '11',
#   '錄取學校': '長庚學校財團法人長庚科技大學',
#   '錄取系所': '護理系（林口校區）',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831412,
#   '班級': '314',
#   '座號': '12',
#   '錄取學校': '台南應用科技大學',
#   '錄取系所': '美容造型設計系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831413,
#   '班級': '314',
#   '座號': '13',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '動物科學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831414,
#   '班級': '314',
#   '座號': '14',
#   '錄取學校': '長庚學校財團法人長庚科技大學',
#   '錄取系所': '護理系（林口校區）',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831415,
#   '班級': '314',
#   '座號': '15',
#   '錄取學校': '經國管理暨健康學院',
#   '錄取系所': '護理系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831416,
#   '班級': '314',
#   '座號': '16',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '中國戲劇學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831417,
#   '班級': '314',
#   '座號': '17',
#   '錄取學校': '中華大學',
#   '錄取系所': '資訊工程學系',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26831418,
#   '班級': '314',
#   '座號': '18',
#   '錄取學校': '長庚大學',
#   '錄取系所': '工商管理學系(數智商務組)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831419,
#   '班級': '314',
#   '座號': '19',
#   '錄取學校': '大葉大學',
#   '錄取系所': '護理學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831420,
#   '班級': '314',
#   '座號': '20',
#   '錄取學校': '元智大學',
#   '錄取系所': '化學工程與材料科學學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831421,
#   '班級': '314',
#   '座號': '21',
#   '錄取學校': '東南科技大學',
#   '錄取系所': '工程與電資學院專班',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831422,
#   '班級': '314',
#   '座號': '22',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '英國語文學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831423,
#   '班級': '314',
#   '座號': '23',
#   '錄取學校': '國立嘉義大學',
#   '錄取系所': '木質材料與設計學系',
#   '入學管道': '身障'},
#  {'學測報名序號': 26831424,
#   '班級': '314',
#   '座號': '24',
#   '錄取學校': '國立東華大學',
#   '錄取系所': '幼兒教育學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831425,
#   '班級': '314',
#   '座號': '25',
#   '錄取學校': '中原大學',
#   '錄取系所': '化學工程學系綠能製程組',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831427,
#   '班級': '314',
#   '座號': '27',
#   '錄取學校': '國立宜蘭大學',
#   '錄取系所': '食品科學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831428,
#   '班級': '314',
#   '座號': '28',
#   '錄取學校': '國立宜蘭大學',
#   '錄取系所': '化學工程與材料工程學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831429,
#   '班級': '314',
#   '座號': '29',
#   '錄取學校': '中華大學',
#   '錄取系所': '資訊工程學系資訊工程組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831430,
#   '班級': '314',
#   '座號': '30',
#   '錄取學校': '元培醫事科技大學',
#   '錄取系所': '生物科技暨製藥技術系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831431,
#   '班級': '314',
#   '座號': '31',
#   '錄取學校': '國立臺灣海洋大學',
#   '錄取系所': '環境生物與漁業科學學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831432,
#   '班級': '314',
#   '座號': '32',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '生命科學系',
#   '入學管道': '獨招'},
#  {'學測報名序號': 26831433,
#   '班級': '314',
#   '座號': '33',
#   '錄取學校': '國立嘉義大學',
#   '錄取系所': '農藝學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831434,
#   '班級': '314',
#   '座號': '34',
#   '錄取學校': '國立聯合大學',
#   '錄取系所': '電機工程學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831435,
#   '班級': '314',
#   '座號': '35',
#   '錄取學校': '元智大學',
#   '錄取系所': '電機工程學系(丙組)',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831436,
#   '班級': '314',
#   '座號': '36',
#   '錄取學校': '淡江大學',
#   '錄取系所': '化學工程與材料工程學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831437,
#   '班級': '314',
#   '座號': '37',
#   '錄取學校': '臺北市立大學',
#   '錄取系所': '休閒運動管理學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831501,
#   '班級': '315',
#   '座號': '01',
#   '錄取學校': '中華醫事科技大學',
#   '錄取系所': '護理系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831502,
#   '班級': '315',
#   '座號': '02',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '經濟學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831503,
#   '班級': '315',
#   '座號': '03',
#   '錄取學校': '長庚學校財團法人長庚科技大學',
#   '錄取系所': '護理系（林口校區）',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831504,
#   '班級': '315',
#   '座號': '04',
#   '錄取學校': '國立宜蘭大學',
#   '錄取系所': '食品科學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831505,
#   '班級': '315',
#   '座號': '05',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '化學工程與材料工程學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831506,
#   '班級': '315',
#   '座號': '06',
#   '錄取學校': '國立聯合大學',
#   '錄取系所': '華語文學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831507,
#   '班級': '315',
#   '座號': '07',
#   '錄取學校': '中山醫學大學',
#   '錄取系所': '物理治療學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831508,
#   '班級': '315',
#   '座號': '08',
#   '錄取學校': '長庚大學',
#   '錄取系所': '人工智慧學士學位學程',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831509,
#   '班級': '315',
#   '座號': '09',
#   '錄取學校': '實踐大學',
#   '錄取系所': '休閒產業管理學系遊憩運動企劃組(高雄校區)',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831510,
#   '班級': '315',
#   '座號': '10',
#   '錄取學校': '長庚學校財團法人長庚科技大學',
#   '錄取系所': '護理系（林口校區）',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831511,
#   '班級': '315',
#   '座號': '11',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '動物科學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831514,
#   '班級': '315',
#   '座號': '14',
#   '錄取學校': '慈濟學校財團法人慈濟科技大學',
#   '錄取系所': '醫務暨健康管理系',
#   '入學管道': '四技二專'},
#  {'學測報名序號': 26831515,
#   '班級': '315',
#   '座號': '15',
#   '錄取學校': '輔仁大學',
#   '錄取系所': '織品服裝設計系',
#   '入學管道': '體優'},
#  {'學測報名序號': 26831517,
#   '班級': '315',
#   '座號': '17',
#   '錄取學校': '靜宜大學',
#   '錄取系所': '食品營養學系食品與生物技術組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831518,
#   '班級': '315',
#   '座號': '18',
#   '錄取學校': '東海大學',
#   '錄取系所': '景觀學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831519,
#   '班級': '315',
#   '座號': '19',
#   '錄取學校': '國立陽明交通大學',
#   '錄取系所': '旋坤揚帆招生戊組(人文社會)',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831520,
#   '班級': '315',
#   '座號': '20',
#   '錄取學校': '國立宜蘭大學',
#   '錄取系所': '電機工程學系',
#   '入學管道': '繁星'},
#  {'學測報名序號': 26831521,
#   '班級': '315',
#   '座號': '21',
#   '錄取學校': '國立東華大學',
#   '錄取系所': '物理學系物理組',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831522,
#   '班級': '315',
#   '座號': '22',
#   '錄取學校': '國立宜蘭大學',
#   '錄取系所': '土木工程學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831524,
#   '班級': '315',
#   '座號': '24',
#   '錄取學校': '長庚大學',
#   '錄取系所': '工商管理學系(工業管理組)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831525,
#   '班級': '315',
#   '座號': '25',
#   '錄取學校': '實踐大學',
#   '錄取系所': '資訊管理學系物聯網應用組(高雄校區)',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831526,
#   '班級': '315',
#   '座號': '26',
#   '錄取學校': '東海大學',
#   '錄取系所': '畜產與生物科技學系(A組)',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831527,
#   '班級': '315',
#   '座號': '27',
#   '錄取學校': '真理大學',
#   '錄取系所': '統計資訊與精算學系商業應用組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831528,
#   '班級': '315',
#   '座號': '28',
#   '錄取學校': '淡江大學',
#   '錄取系所': '理學院尖端材料科學學士學位學程',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831529,
#   '班級': '315',
#   '座號': '29',
#   '錄取學校': '靜宜大學',
#   '錄取系所': '法律學系',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831530,
#   '班級': '315',
#   '座號': '30',
#   '錄取學校': '中華大學',
#   '錄取系所': '資訊工程學系資訊應用組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831531,
#   '班級': '315',
#   '座號': '31',
#   '錄取學校': '中原大學',
#   '錄取系所': '化學系化學組',
#   '入學管道': '分科'},
#  {'學測報名序號': 26831532,
#   '班級': '315',
#   '座號': '32',
#   '錄取學校': '國立宜蘭大學',
#   '錄取系所': '園藝學系',
#   '入學管道': '身障'},
#  {'學測報名序號': 26831533,
#   '班級': '315',
#   '座號': '33',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '商品設計學系（桃園校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831534,
#   '班級': '315',
#   '座號': '34',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '資訊管理學系雲端技術管理組（桃園校區）',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831535,
#   '班級': '315',
#   '座號': '35',
#   '錄取學校': '中國文化大學',
#   '錄取系所': '經濟學系',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831536,
#   '班級': '315',
#   '座號': '36',
#   '錄取學校': '淡江大學',
#   '錄取系所': '數學學系資料科學與數理統計組',
#   '入學管道': '申請'},
#  {'學測報名序號': 26831537,
#   '班級': '315',
#   '座號': '37',
#   '錄取學校': '銘傳大學',
#   '錄取系所': '資訊工程學系(桃園校區)',
#   '入學管道': '申請'}]

# %%
# Q1 輸入學測報名序號，找出其相關信息

# 輸入學測報名序號
search_id = input("請輸入學測報名序號：")

# 查找信息
found = False
for student_info in data:
    if student_info.get('學測報名序號') == search_id:
        print("學測報名序號：", student_info.get('學測報名序號'))
        print("班級：", student_info.get('班級'))
        print("座號：", student_info.get('座號'))
        print("錄取學校：", student_info.get('錄取學校'))
        print("錄取系所：", student_info.get('錄取系所'))
        print("入學管道：", student_info.get('入學管道'))
        found = True
        
if not found:
    print("找不到該學測報名序號")
# Out:
# 請輸入學測報名序號：26831301
# 找不到該學測報名序號

# %%
# Q2 輸入錄取學校，查看有哪些考生錄取該校的什麼系所

# 輸入學校
search_school = input("請輸入錄取學校：")

# 查找信息
found = False
for student_info in sorted_data:
     if student_info.get('錄取學校') == search_school:
            print("學測報名序號：", student_info.get('學測報名序號'))
            print("班級：", student_info.get('班級'))
            print("座號：", student_info.get('座號'))
            print("錄取系所：", student_info.get('錄取系所'))
            found = True
            
            
if not found:
    print("找不到該錄取學校")
# Out:
# 請輸入錄取學校：國立臺灣師範大學
# 學測報名序號： 26831118
# 班級： 311
# 座號： 18
# 錄取系所： 物理學系
# 學測報名序號： 26831301
# 班級： 313
# 座號： 01
# 錄取系所： 科技應用與人力資源發展學系

# %%
# Q3 輸入入學管道，查看有哪些考生是利用該管道入學的且錄取什麼校系

# 輸入入學管道
search_function = input("請輸入入學管道：")

# 查找信息
found = False
for student_info in sorted_data:
     if student_info.get('入學管道') == search_function:
            print("學測報名序號：", student_info.get('學測報名序號'))
            print("班級：", student_info.get('班級'))
            print("座號：", student_info.get('座號'))
            print("錄取學校：", student_info.get('錄取學校'))
            print("錄取系所：", student_info.get('錄取系所'))
            found = True
            
            
if not found:
    print("找不到該入學管道")
# Out:
# 請輸入入學管道：申請
# 學測報名序號： 26830101
# 班級： 301
# 座號： 01
# 錄取學校： 真理大學
# 錄取系所： 企業管理學系
# 學測報名序號： 26830102
# 班級： 301
# 座號： 02
# 錄取學校： 臺北市立大學
# 錄取系所： 教育學系
# 學測報名序號： 26830103
# 班級： 301
# 座號： 03
# 錄取學校： 世新大學
# 錄取系所： 觀光學系觀光規劃暨資源管理組
# 學測報名序號： 26830104
# 班級： 301
# 座號： 04
# 錄取學校： 世新大學
# 錄取系所： 日本語文學系
# 學測報名序號： 26830106
# 班級： 301
# 座號： 06
# 錄取學校： 高雄醫學大學
# 錄取系所： 醫學社會學與社會工作學系
# 學測報名序號： 26830107
# 班級： 301
# 座號： 07
# 錄取學校： 實踐大學
# 錄取系所： 服飾設計與經營學系藝術創作設計組(高雄校區)
# 學測報名序號： 26830116
# 班級： 301
# 座號： 16
# 錄取學校： 佛光大學
# 錄取系所： 外國語文學系
# 學測報名序號： 26830118
# 班級： 301
# 座號： 18
# 錄取學校： 真理大學
# 錄取系所： 觀光事業學系餐旅管理組
# 學測報名序號： 26830119
# 班級： 301
# 座號： 19
# 錄取學校： 實踐大學
# 錄取系所： 服裝設計學系(臺北校區)
# 學測報名序號： 26830121
# 班級： 301
# 座號： 21
# 錄取學校： 銘傳大學
# 錄取系所： 醫療資訊與管理學系健康產業管理組（桃園校區）
# 學測報名序號： 26830122
# 班級： 301
# 座號： 22
# 錄取學校： 元智大學
# 錄取系所： 中國語文學系
# 學測報名序號： 26830123
# 班級： 301
# 座號： 23
# 錄取學校： 世新大學
# 錄取系所： 行政管理學系
# 學測報名序號： 26830132
# 班級： 301
# 座號： 32
# 錄取學校： 義守大學
# 錄取系所： 應用英語學系
# 學測報名序號： 26830203
# 班級： 302
# 座號： 03
# 錄取學校： 銘傳大學
# 錄取系所： 企業管理學系品牌行銷組（臺北校區）
# 學測報名序號： 26830206
# 班級： 302
# 座號： 06
# 錄取學校： 中國文化大學
# 錄取系所： 韓國語文學系
# 學測報名序號： 26830207
# 班級： 302
# 座號： 07
# 錄取學校： 亞洲大學
# 錄取系所： 財經法律學系科技法律組
# 學測報名序號： 26830208
# 班級： 302
# 座號： 08
# 錄取學校： 銘傳大學
# 錄取系所： 動漫文創設計學士學位學程（桃園校區）
# 學測報名序號： 26830213
# 班級： 302
# 座號： 13
# 錄取學校： 中國文化大學
# 錄取系所： 勞動暨人力資源學系
# 學測報名序號： 26830221
# 班級： 302
# 座號： 21
# 錄取學校： 中華大學
# 錄取系所： 景觀建築學系產品設計組
# 學測報名序號： 26830222
# 班級： 302
# 座號： 22
# 錄取學校： 東海大學
# 錄取系所： 社會工作學系
# 學測報名序號： 26830229
# 班級： 302
# 座號： 29
# 錄取學校： 銘傳大學
# 錄取系所： 商品設計學系（桃園校區）
# 學測報名序號： 26830230
# 班級： 302
# 座號： 30
# 錄取學校： 淡江大學
# 錄取系所： 全球政治經濟學系全英語學士班
# 學測報名序號： 26830303
# 班級： 303
# 座號： 03
# 錄取學校： 世新大學
# 錄取系所： 法律學系
# 學測報名序號： 26830305
# 班級： 303
# 座號： 05
# 錄取學校： 銘傳大學
# 錄取系所： 觀光事業學系（桃園校區）
# 學測報名序號： 26830309
# 班級： 303
# 座號： 09
# 錄取學校： 淡江大學
# 錄取系所： 教育科技學系
# 學測報名序號： 26830311
# 班級： 303
# 座號： 11
# 錄取學校： 亞洲大學
# 錄取系所： 休閒與遊憩管理學系餐旅事業管理組
# 學測報名序號： 26830317
# 班級： 303
# 座號： 17
# 錄取學校： 玄奘大學
# 錄取系所： 應用心理學系
# 學測報名序號： 26830318
# 班級： 303
# 座號： 18
# 錄取學校： 開南大學
# 錄取系所： 國際物流與運輸管理學系
# 學測報名序號： 26830322
# 班級： 303
# 座號： 22
# 錄取學校： 真理大學
# 錄取系所： 應用日語學系
# 學測報名序號： 26830323
# 班級： 303
# 座號： 23
# 錄取學校： 世新大學
# 錄取系所： 新聞學系
# 學測報名序號： 26830324
# 班級： 303
# 座號： 24
# 錄取學校： 世新大學
# 錄取系所： 圖文傳播暨數位出版學系
# 學測報名序號： 26830326
# 班級： 303
# 座號： 26
# 錄取學校： 開南大學
# 錄取系所： 電影與創意媒體學系
# 學測報名序號： 26830327
# 班級： 303
# 座號： 27
# 錄取學校： 中國文化大學
# 錄取系所： 都市計劃與開發管理學系
# 學測報名序號： 26830328
# 班級： 303
# 座號： 28
# 錄取學校： 大同大學
# 錄取系所： 事業經營學系
# 學測報名序號： 26830329
# 班級： 303
# 座號： 29
# 錄取學校： 實踐大學
# 錄取系所： 休閒產業管理學系休閒文創規劃組(高雄校區)
# 學測報名序號： 26830330
# 班級： 303
# 座號： 30
# 錄取學校： 佛光大學
# 錄取系所： 歷史學系(A組)
# 學測報名序號： 26830332
# 班級： 303
# 座號： 32
# 錄取學校： 中國文化大學
# 錄取系所： 日本語文學系
# 學測報名序號： 26830402
# 班級： 304
# 座號： 02
# 錄取學校： 銘傳大學
# 錄取系所： 觀光事業學系（桃園校區）
# 學測報名序號： 26830405
# 班級： 304
# 座號： 05
# 錄取學校： 真理大學
# 錄取系所： 人文與資訊學系一般組
# 學測報名序號： 26830406
# 班級： 304
# 座號： 06
# 錄取學校： 佛光大學
# 錄取系所： 中國文學與應用學系
# 學測報名序號： 26830410
# 班級： 304
# 座號： 10
# 錄取學校： 佛光大學
# 錄取系所： 心理學系
# 學測報名序號： 26830411
# 班級： 304
# 座號： 11
# 錄取學校： 銘傳大學
# 錄取系所： 企業管理學系品牌行銷組（臺北校區）
# 學測報名序號： 26830420
# 班級： 304
# 座號： 20
# 錄取學校： 世新大學
# 錄取系所： 日本語文學系
# 學測報名序號： 26830421
# 班級： 304
# 座號： 21
# 錄取學校： 銘傳大學
# 錄取系所： 應用日語學系（桃園校區）
# 學測報名序號： 26830424
# 班級： 304
# 座號： 24
# 錄取學校： 銘傳大學
# 錄取系所： 華語文教學學系應用語言組（桃園校區）
# 學測報名序號： 26830426
# 班級： 304
# 座號： 26
# 錄取學校： 銘傳大學
# 錄取系所： 應用中國文學系文教組（桃園校區）
# 學測報名序號： 26830427
# 班級： 304
# 座號： 27
# 錄取學校： 國立金門大學
# 錄取系所： 觀光管理學系
# 學測報名序號： 26830428
# 班級： 304
# 座號： 28
# 錄取學校： 中國文化大學
# 錄取系所： 新聞學系
# 學測報名序號： 26830431
# 班級： 304
# 座號： 31
# 錄取學校： 真理大學
# 錄取系所： 應用日語學系
# 學測報名序號： 26830501
# 班級： 305
# 座號： 01
# 錄取學校： 東吳大學
# 錄取系所： 哲學系
# 學測報名序號： 26830502
# 班級： 305
# 座號： 02
# 錄取學校： 中國文化大學
# 錄取系所： 觀光事業學系
# 學測報名序號： 26830507
# 班級： 305
# 座號： 07
# 錄取學校： 國立金門大學
# 錄取系所： 國際暨大陸事務學系
# 學測報名序號： 26830509
# 班級： 305
# 座號： 09
# 錄取學校： 開南大學
# 錄取系所： 國際物流與運輸管理學系
# 學測報名序號： 26830513
# 班級： 305
# 座號： 13
# 錄取學校： 銘傳大學
# 錄取系所： 企業管理學系企業管理組（臺北校區）
# 學測報名序號： 26830518
# 班級： 305
# 座號： 18
# 錄取學校： 靜宜大學
# 錄取系所： 會計學系
# 學測報名序號： 26830520
# 班級： 305
# 座號： 20
# 錄取學校： 真理大學
# 錄取系所： 運動管理學系
# 學測報名序號： 26830523
# 班級： 305
# 座號： 23
# 錄取學校： 玄奘大學
# 錄取系所： 社會工作學系
# 學測報名序號： 26830527
# 班級： 305
# 座號： 27
# 錄取學校： 中國文化大學
# 錄取系所： 資訊傳播學系
# 學測報名序號： 26830528
# 班級： 305
# 座號： 28
# 錄取學校： 靜宜大學
# 錄取系所： 會計學系
# 學測報名序號： 26830530
# 班級： 305
# 座號： 30
# 錄取學校： 中國文化大學
# 錄取系所： 都市計劃與開發管理學系
# 學測報名序號： 26830532
# 班級： 305
# 座號： 32
# 錄取學校： 中國文化大學
# 錄取系所： 國際企業管理學系
# 學測報名序號： 26830533
# 班級： 305
# 座號： 33
# 錄取學校： 長庚大學
# 錄取系所： 工商管理學系工業管理組
# 學測報名序號： 26830534
# 班級： 305
# 座號： 34
# 錄取學校： 淡江大學
# 錄取系所： 國際企業學系經貿管理組
# 學測報名序號： 26830535
# 班級： 305
# 座號： 35
# 錄取學校： 中國文化大學
# 錄取系所： 國際企業管理學系
# 學測報名序號： 26830536
# 班級： 305
# 座號： 36
# 錄取學校： 義守大學
# 錄取系所： 數位多媒體設計學系
# 學測報名序號： 26830601
# 班級： 306
# 座號： 01
# 錄取學校： 東吳大學
# 錄取系所： 英文學系
# 學測報名序號： 26830602
# 班級： 306
# 座號： 02
# 錄取學校： 銘傳大學
# 錄取系所： 休閒遊憩管理學系（桃園校區）
# 學測報名序號： 26830604
# 班級： 306
# 座號： 04
# 錄取學校： 靜宜大學
# 錄取系所： 財務金融學系
# 學測報名序號： 26830605
# 班級： 306
# 座號： 05
# 錄取學校： 大同大學
# 錄取系所： 應用外語學系
# 學測報名序號： 26830606
# 班級： 306
# 座號： 06
# 錄取學校： 東海大學
# 錄取系所： 高齡健康與運動科學學士學位學程
# 學測報名序號： 26830608
# 班級： 306
# 座號： 08
# 錄取學校： 元智大學
# 錄取系所： 管理學院學士班(主修：企業管理)
# 學測報名序號： 26830614
# 班級： 306
# 座號： 14
# 錄取學校： 銘傳大學
# 錄取系所： 國際企業學系外貿行銷管理組（臺北校區）
# 學測報名序號： 26830620
# 班級： 306
# 座號： 20
# 錄取學校： 銘傳大學
# 錄取系所： 國際企業學系外貿行銷管理組（臺北校區）
# 學測報名序號： 26830623
# 班級： 306
# 座號： 23
# 錄取學校： 靜宜大學
# 錄取系所： 財務金融學系
# 學測報名序號： 26830627
# 班級： 306
# 座號： 27
# 錄取學校： 中國文化大學
# 錄取系所： 觀光事業學系
# 學測報名序號： 26830632
# 班級： 306
# 座號： 32
# 錄取學校： 中國文化大學
# 錄取系所： 資訊傳播學系
# 學測報名序號： 26830636
# 班級： 306
# 座號： 36
# 錄取學校： 開南大學
# 錄取系所： 觀光與餐飲旅館學系
# 學測報名序號： 26830704
# 班級： 307
# 座號： 04
# 錄取學校： 銘傳大學
# 錄取系所： 會計學系稅務規劃組（臺北校區）
# 學測報名序號： 26830708
# 班級： 307
# 座號： 08
# 錄取學校： 銘傳大學
# 錄取系所： 應用中國文學系文教組（桃園校區）
# 學測報名序號： 26830709
# 班級： 307
# 座號： 09
# 錄取學校： 銘傳大學
# 錄取系所： 應用統計與資料科學學系大數據管理組（桃園校區）
# 學測報名序號： 26830710
# 班級： 307
# 座號： 10
# 錄取學校： 銘傳大學
# 錄取系所： 應用英語學系英語商務組（桃園校區）
# 學測報名序號： 26830718
# 班級： 307
# 座號： 18
# 錄取學校： 真理大學
# 錄取系所： 統計資訊與精算學系商業應用組
# 學測報名序號： 26830720
# 班級： 307
# 座號： 20
# 錄取學校： 銘傳大學
# 錄取系所： 風險管理與保險學系保險金融與行銷組（臺北校區）
# 學測報名序號： 26830722
# 班級： 307
# 座號： 22
# 錄取學校： 淡江大學
# 錄取系所： 資訊傳播學系
# 學測報名序號： 26830723
# 班級： 307
# 座號： 23
# 錄取學校： 實踐大學
# 錄取系所： 應用中文學系劇本創作組(高雄校區)
# 學測報名序號： 26830725
# 班級： 307
# 座號： 25
# 錄取學校： 國立暨南國際大學
# 錄取系所： 社會政策與社會工作學系
# 學測報名序號： 26830726
# 班級： 307
# 座號： 26
# 錄取學校： 淡江大學
# 錄取系所： 統計學系
# 學測報名序號： 26830728
# 班級： 307
# 座號： 28
# 錄取學校： 亞洲大學
# 錄取系所： 財經法律學系財經法律組
# 學測報名序號： 26830731
# 班級： 307
# 座號： 31
# 錄取學校： 銘傳大學
# 錄取系所： 經濟與金融學系產業經濟組（桃園校區）
# 學測報名序號： 26830801
# 班級： 308
# 座號： 01
# 錄取學校： 銘傳大學
# 錄取系所： 應用統計與資料科學學系大數據管理組（桃園校區）
# 學測報名序號： 26830806
# 班級： 308
# 座號： 06
# 錄取學校： 實踐大學
# 錄取系所： 會計學系(臺北校區)
# 學測報名序號： 26830808
# 班級： 308
# 座號： 08
# 錄取學校： 世新大學
# 錄取系所： 行政管理學系
# 學測報名序號： 26830813
# 班級： 308
# 座號： 13
# 錄取學校： 淡江大學
# 錄取系所： 資訊管理學系
# 學測報名序號： 26830814
# 班級： 308
# 座號： 14
# 錄取學校： 玄奘大學
# 錄取系所： 時尚設計學系
# 學測報名序號： 26830816
# 班級： 308
# 座號： 16
# 錄取學校： 世新大學
# 錄取系所： 企業管理學系
# 學測報名序號： 26830817
# 班級： 308
# 座號： 17
# 錄取學校： 輔仁大學
# 錄取系所： 宗教學系
# 學測報名序號： 26830818
# 班級： 308
# 座號： 18
# 錄取學校： 世新大學
# 錄取系所： 觀光學系旅遊暨休閒事業管理組
# 學測報名序號： 26830819
# 班級： 308
# 座號： 19
# 錄取學校： 佛光大學
# 錄取系所： 產品與媒體設計學系（創意產品設計組）
# 學測報名序號： 26830825
# 班級： 308
# 座號： 25
# 錄取學校： 真理大學
# 錄取系所： 運動管理學系
# 學測報名序號： 26830828
# 班級： 308
# 座號： 28
# 錄取學校： 真理大學
# 錄取系所： 應用日語學系
# 學測報名序號： 26830836
# 班級： 308
# 座號： 36
# 錄取學校： 真理大學
# 錄取系所： 經濟學系
# 學測報名序號： 26830901
# 班級： 309
# 座號： 01
# 錄取學校： 銘傳大學
# 錄取系所： 醫療資訊與管理學系健康產業管理組（桃園校區）
# 學測報名序號： 26830906
# 班級： 309
# 座號： 06
# 錄取學校： 淡江大學
# 錄取系所： 歷史學系
# 學測報名序號： 26830907
# 班級： 309
# 座號： 07
# 錄取學校： 銘傳大學
# 錄取系所： 風險管理與保險學系風險管理組（臺北校區）
# 學測報名序號： 26830913
# 班級： 309
# 座號： 13
# 錄取學校： 佛光大學
# 錄取系所： 應用經濟學系(國際商務組)
# 學測報名序號： 26830914
# 班級： 309
# 座號： 14
# 錄取學校： 銘傳大學
# 錄取系所： 公共事務與行政管理學系（桃園校區）
# 學測報名序號： 26830918
# 班級： 309
# 座號： 18
# 錄取學校： 佛光大學
# 錄取系所： 社會學暨社會工作學系
# 學測報名序號： 26830927
# 班級： 309
# 座號： 27
# 錄取學校： 真理大學
# 錄取系所： 企業管理學系
# 學測報名序號： 26830933
# 班級： 309
# 座號： 33
# 錄取學校： 實踐大學
# 錄取系所： 金融管理學系金融商品組(高雄校區)
# 學測報名序號： 26831005
# 班級： 310
# 座號： 05
# 錄取學校： 南華大學
# 錄取系所： 建築與景觀學系自然組
# 學測報名序號： 26831007
# 班級： 310
# 座號： 07
# 錄取學校： 大葉大學
# 錄取系所： 環境工程學系(環境管理組)
# 學測報名序號： 26831009
# 班級： 310
# 座號： 09
# 錄取學校： 國立宜蘭大學
# 錄取系所： 生物機電工程學系
# 學測報名序號： 26831011
# 班級： 310
# 座號： 11
# 錄取學校： 佛光大學
# 錄取系所： 應用經濟學系(國際商務組)
# 學測報名序號： 26831019
# 班級： 310
# 座號： 19
# 錄取學校： 佛光大學
# 錄取系所： 產品與媒體設計學系（創意產品設計組）
# 學測報名序號： 26831020
# 班級： 310
# 座號： 20
# 錄取學校： 中原大學
# 錄取系所： 物理學系物理組
# 學測報名序號： 26831022
# 班級： 310
# 座號： 22
# 錄取學校： 佛光大學
# 錄取系所： 中國文學與應用學系
# 學測報名序號： 26831031
# 班級： 310
# 座號： 31
# 錄取學校： 佛光大學
# 錄取系所： 資訊應用學系(數位遊戲開發組)
# 學測報名序號： 26831101
# 班級： 311
# 座號： 01
# 錄取學校： 中原大學
# 錄取系所： 土木工程學系
# 學測報名序號： 26831108
# 班級： 311
# 座號： 08
# 錄取學校： 逢甲大學
# 錄取系所： 運輸與物流學系
# 學測報名序號： 26831113
# 班級： 311
# 座號： 13
# 錄取學校： 中原大學
# 錄取系所： 工業與系統工程學系工程組
# 學測報名序號： 26831115
# 班級： 311
# 座號： 15
# 錄取學校： 佛光大學
# 錄取系所： 資訊應用學系(數位遊戲開發組)
# 學測報名序號： 26831116
# 班級： 311
# 座號： 16
# 錄取學校： 中華大學
# 錄取系所： 工業管理學系（乙組）
# 學測報名序號： 26831118
# 班級： 311
# 座號： 18
# 錄取學校： 國立臺灣師範大學
# 錄取系所： 物理學系
# 學測報名序號： 26831119
# 班級： 311
# 座號： 19
# 錄取學校： 中原大學
# 錄取系所： 土木工程學系
# 學測報名序號： 26831120
# 班級： 311
# 座號： 20
# 錄取學校： 銘傳大學
# 錄取系所： 電腦與通訊工程學系（桃園校區）
# 學測報名序號： 26831126
# 班級： 311
# 座號： 26
# 錄取學校： 東海大學
# 錄取系所： 化學工程與材料工程學系(製程及能源工程組)
# 學測報名序號： 26831207
# 班級： 312
# 座號： 07
# 錄取學校： 義守大學
# 錄取系所： 土木工程學系
# 學測報名序號： 26831209
# 班級： 312
# 座號： 09
# 錄取學校： 玄奘大學
# 錄取系所： 大眾傳播學系
# 學測報名序號： 26831211
# 班級： 312
# 座號： 11
# 錄取學校： 淡江大學
# 錄取系所： 統計學系
# 學測報名序號： 26831213
# 班級： 312
# 座號： 13
# 錄取學校： 輔仁大學
# 錄取系所： 物理學系物理組
# 學測報名序號： 26831214
# 班級： 312
# 座號： 14
# 錄取學校： 元智大學
# 錄取系所： 工業工程與管理學系
# 學測報名序號： 26831215
# 班級： 312
# 座號： 15
# 錄取學校： 元智大學
# 錄取系所： 電機通訊學院英語學士班
# 學測報名序號： 26831216
# 班級： 312
# 座號： 16
# 錄取學校： 銘傳大學
# 錄取系所： 電腦與通訊工程學系（桃園校區）
# 學測報名序號： 26831218
# 班級： 312
# 座號： 18
# 錄取學校： 淡江大學
# 錄取系所： 化學學系材料化學組
# 學測報名序號： 26831219
# 班級： 312
# 座號： 19
# 錄取學校： 義守大學
# 錄取系所： 材料科學與工程學系
# 學測報名序號： 26831221
# 班級： 312
# 座號： 21
# 錄取學校： 淡江大學
# 錄取系所： 數學學系數學組
# 學測報名序號： 26831224
# 班級： 312
# 座號： 24
# 錄取學校： 銘傳大學
# 錄取系所： 資訊管理學系雲端技術管理組（桃園校區）
# 學測報名序號： 26831225
# 班級： 312
# 座號： 25
# 錄取學校： 中國文化大學
# 錄取系所： 電機工程學系
# 學測報名序號： 26831227
# 班級： 312
# 座號： 27
# 錄取學校： 國立臺東大學
# 錄取系所： 應用科學系化學及奈米科學組
# 學測報名序號： 26831409
# 班級： 314
# 座號： 09
# 錄取學校： 淡江大學
# 錄取系所： 化學學系化學與生物化學組
# 學測報名序號： 26831410
# 班級： 314
# 座號： 10
# 錄取學校： 中國文化大學
# 錄取系所： 體育學系
# 學測報名序號： 26831413
# 班級： 314
# 座號： 13
# 錄取學校： 中國文化大學
# 錄取系所： 動物科學系
# 學測報名序號： 26831416
# 班級： 314
# 座號： 16
# 錄取學校： 中國文化大學
# 錄取系所： 中國戲劇學系
# 學測報名序號： 26831429
# 班級： 314
# 座號： 29
# 錄取學校： 中華大學
# 錄取系所： 資訊工程學系資訊工程組
# 學測報名序號： 26831435
# 班級： 314
# 座號： 35
# 錄取學校： 元智大學
# 錄取系所： 電機工程學系(丙組)
# 學測報名序號： 26831437
# 班級： 314
# 座號： 37
# 錄取學校： 臺北市立大學
# 錄取系所： 休閒運動管理學系
# 學測報名序號： 26831502
# 班級： 315
# 座號： 02
# 錄取學校： 中國文化大學
# 錄取系所： 經濟學系
# 學測報名序號： 26831506
# 班級： 315
# 座號： 06
# 錄取學校： 國立聯合大學
# 錄取系所： 華語文學系
# 學測報名序號： 26831509
# 班級： 315
# 座號： 09
# 錄取學校： 實踐大學
# 錄取系所： 休閒產業管理學系遊憩運動企劃組(高雄校區)
# 學測報名序號： 26831517
# 班級： 315
# 座號： 17
# 錄取學校： 靜宜大學
# 錄取系所： 食品營養學系食品與生物技術組
# 學測報名序號： 26831519
# 班級： 315
# 座號： 19
# 錄取學校： 國立陽明交通大學
# 錄取系所： 旋坤揚帆招生戊組(人文社會)
# 學測報名序號： 26831525
# 班級： 315
# 座號： 25
# 錄取學校： 實踐大學
# 錄取系所： 資訊管理學系物聯網應用組(高雄校區)
# 學測報名序號： 26831527
# 班級： 315
# 座號： 27
# 錄取學校： 真理大學
# 錄取系所： 統計資訊與精算學系商業應用組
# 學測報名序號： 26831528
# 班級： 315
# 座號： 28
# 錄取學校： 淡江大學
# 錄取系所： 理學院尖端材料科學學士學位學程
# 學測報名序號： 26831530
# 班級： 315
# 座號： 30
# 錄取學校： 中華大學
# 錄取系所： 資訊工程學系資訊應用組
# 學測報名序號： 26831533
# 班級： 315
# 座號： 33
# 錄取學校： 銘傳大學
# 錄取系所： 商品設計學系（桃園校區）
# 學測報名序號： 26831534
# 班級： 315
# 座號： 34
# 錄取學校： 銘傳大學
# 錄取系所： 資訊管理學系雲端技術管理組（桃園校區）
# 學測報名序號： 26831535
# 班級： 315
# 座號： 35
# 錄取學校： 中國文化大學
# 錄取系所： 經濟學系
# 學測報名序號： 26831536
# 班級： 315
# 座號： 36
# 錄取學校： 淡江大學
# 錄取系所： 數學學系資料科學與數理統計組
# 學測報名序號： 26831537
# 班級： 315
# 座號： 37
# 錄取學校： 銘傳大學
# 錄取系所： 資訊工程學系(桃園校區)
